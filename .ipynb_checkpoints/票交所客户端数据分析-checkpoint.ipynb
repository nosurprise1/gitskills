# %% [markdown]
# # 贴现记录表分数

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import flask,os
import hashlib,csv,datetime,time,random
import urllib,json
import urllib.request
import tkinter as tk
from tkinter import ttk
from tkinter import *
from  tkinter import messagebox
import itchat,re
from itchat.content import *
import json
import urllib.request
import requests
import urllib.parse
from matplotlib.font_manager import FontProperties  
import xlrd,xlwt
from tkinter import filedialog

url0='http://www.51tradecloud.com/'

#定义颜色
import ctypes
STD_INPUT_HANDLE = -10
STD_OUTPUT_HANDLE= -11
STD_ERROR_HANDLE = -12
FOREGROUND_BLACK = 0x0
FOREGROUND_BLUE = 0x01 # text color contains blue.
FOREGROUND_GREEN= 0x02 # text color contains green.
FOREGROUND_RED = 0x04 # text color contains red.
FOREGROUND_INTENSITY = 0x08 # text color is intensified.
BACKGROUND_BLUE = 0x10 # background color contains blue.
BACKGROUND_GREEN= 0x20 # background color contains green.
BACKGROUND_RED = 0x40 # background color contains red.
BACKGROUND_INTENSITY = 0x80 # background color is intensified.

FOREGROUND_SKYBLUE = 0x0b # skyblue.
FOREGROUND_RED = 0x0c # red.
FOREGROUND_PINK = 0x0d # pink.
FOREGROUND_YELLOW = 0x0e # yellow.
FOREGROUND_WHITE = 0x0f # white.

class Color:

    std_out_handle = ctypes.windll.kernel32.GetStdHandle(STD_OUTPUT_HANDLE)
    def set_cmd_color(self, color, handle=std_out_handle):

        bool = ctypes.windll.kernel32.SetConsoleTextAttribute(handle, color)
        return bool
    def reset_color(self):
        self.set_cmd_color(FOREGROUND_RED | FOREGROUND_GREEN | FOREGROUND_BLUE)
    def print_red_text(self, print_text):
        self.set_cmd_color(FOREGROUND_RED | FOREGROUND_INTENSITY)
        print(print_text)
        self.reset_color()
    def print_green_text(self, print_text):
        self.set_cmd_color(FOREGROUND_GREEN | FOREGROUND_INTENSITY)
        print(print_text)
        self.reset_color()
    def print_blue_text(self, print_text):
        self.set_cmd_color(FOREGROUND_SKYBLUE | FOREGROUND_INTENSITY)
        print(print_text)
        self.reset_color()

    def print_white_text(self, print_text):
        self.set_cmd_color(FOREGROUND_WHITE | FOREGROUND_INTENSITY)
        print(print_text)
        
    def print_red_text_with_white_bg(self, print_text):
        self.set_cmd_color(FOREGROUND_BLACK | FOREGROUND_INTENSITY| BACKGROUND_WHITE | BACKGROUND_INTENSITY)
        print(print_text)
        self.reset_color()

clr = Color()
        




#一、监控微信


conji=0
content=[]   #用于过滤已经接收过的广告




@itchat.msg_register(['Picture','Recording','Attachment','Video'])
def download_files(msg):
      friend=itchat.search_friends(userName=msg['FromUserName'])
      co=re.compile(u'[\U00010000-\U0010ffff]')
      friend2=co.sub(u'',friend['NickName'])
      remarkname=co.sub(u'',str(friend['RemarkName']))
      path = os.getcwd()#获取当前路径


      msg['Text'](path+'/下载文件/私信/'+msg['FileName'])
      clr.print_red_text('私信：收到%s(%s)发来的一个文件，已存入根目录。'%(friend2,remarkname))


@itchat.msg_register(['Picture','Recording','Attachment','Video'], isGroupChat = True)
def download_files2(msg):
      global yaokan,yaokan2
      co=re.compile(u'[\U00010000-\U0010ffff]')

      chatrooms1 = itchat.search_chatrooms(userName=msg['FromUserName'])#关键是看群名，与是否保存到通讯录无关
      qunming2=co.sub(u'',chatrooms1['NickName'])
      guanjian=0
      if len(yaokan2)!=0:
        for i in yaokan2:
          if i in qunming2:
              guanjian=1
        
      if (qunming2 in yaokan) or (guanjian==1):

          name2=co.sub(u'',msg['ActualNickName'])
        #  name=msg['ActualNickName']


          
          clr.print_red_text('群聊：收到%s发在群%s中的一个文件，已存入根目录。'%(name2,qunming2))

          path = os.getcwd()#获取当前路径


          msg['Text'](path+'/下载文件/群聊/'+msg['FileName'])

      

@itchat.msg_register(TEXT, isGroupChat = True)
def groupchat_reply(msg):
      global content,conji,url0,bufa,username2,dict_nickname,shan_df1,shan_df2,yaokan,yaokan2
      maxTryNum=10
      hanglei1='中介'
      hanglei2=0
      hanglei3=0
      shou=0
      chu=0
      shoudai=0
      chudai=0
      shouhui=0
      chuhui=0
      shoufu=0
      chufu=0
      shouli=0
      chuli=0
      shoucun=0
      chucun=0
      co=msg['Content']
      killci=''
      guanggao=''
    #给df2赋值
      co=re.compile(u'[\U00010000-\U0010ffff]')

      coo=co.sub(u'',str(msg['Content']).strip())   #排除前后的空格
      cooo=coo
      coo=coo.replace('托收票','票').replace('收益','')
 #   end1 = time.time()




#凡是中介发的消息，不做分析
      string=re.split('；|。|？|！|~~|，| |…',coo)
      num=len(string)

#18957170906的群挑选   
      chatrooms1 = itchat.search_chatrooms(userName=msg['FromUserName'])#关键是看群名，与是否保存到通讯录无关

      qunming2=co.sub(u'',chatrooms1['NickName'])
      name2=co.sub(u'',msg['ActualNickName'])    #name2是为了输出精简过的  ；name才是准确的

      name=msg['ActualNickName']

      guanjian=0
      if len(yaokan2)!=0:
        for i in yaokan2:
          if i in qunming2:
              guanjian=1
        
      if (qunming2 in yaokan) or (guanjian==1):


           shijian1=time.strftime('%Y-%m-%d',time.localtime(time.time()))
           shijian2=time.strftime('%H:%M',time.localtime(time.time()))
           print("重点群聊（全部消息显示）：%s"%qunming2),
           print('昵称：%s  %s'%(name2,shijian2))      #输出在本群的昵称？还是自己的备注名？
           print("内容：%s"%coo)
           print('\n')

           return

      elif  ('股票' in coo) or ('票据群' in coo) or ('门票' in coo):
          return


            
      else:
          if conji>=100:
            conji=0
            content=[]


          if (coo not in content) :  #如果今天自己的号没有爬过
             content.append(coo)                 
             conji=conji+1

  #一、票据业务       
             zhaop= re.search('^((?!(谁|有人)).)*(?:收)[^。,，！…；~？]*(?:回购|买返|买入返售)((?!(吗|么|找|联系|？)).)*$',coo)
             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:出)[^。,，！…；~？]*(?:回购|买返|买入返售)',coo)
             zhaop2= re.search('(?:出)[^。,，！…；~？]*(?:回购|买返|买入返售)[^。,，！…；~]*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2:
                  shouhui='1'
        

             zhaop= re.search('^((?!(谁|有人)).)*(?:收)[^。,，！…；~？]*(?:代持)((?!(吗|么|找|联系|？)).)*$',coo)
             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:出)[^。,，！…；~？]*(?:代持)',coo)
             zhaop2= re.search('(?:出)[^。,，！…；~？]*(?:代持)[^。,，！…；~]*(?:吗|么|找|联系|？)',coo)
             if zhaop or zhaop1 or zhaop2:
                  shoudai='1'
                  guanggao=guanggao+'收代持'


             zhaop= re.search('^((?!(谁|有人)).)*(?:收|买)[^。,，！…；~？]*(?:票|电银|足月|足年|\d月|农商|国股|城商)((?!(买返|买入返售|回购|代持|吗|么|找|联系|？)).)*$',coo)
             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:出|卖)[^。,，！…；~？]*(?:票|电银|足月|足年|\d月|农商|国股|城商)((?!(买返|买入返售|回购|代持)).)*$',coo)
             zhaop2= re.search('(?:出|卖)[^。,，！…；~？]*(?:票|电银|足月|足年|\d月|农商|国股|城商)[^。,，！…；~？]*((?!(买返|买入返售|回购|代持|。|,|，|！|…|；|~)).)*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2:
                 shou='1'

                 guanggao=guanggao+'收票'


             zhaop= re.search('^((?!(谁|有人)).)*(?:出)[^。,，！…；~？]*(?:回购|买返|买入返售)((?!(吗|么|找|联系|？)).)*$',coo)
             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:收)[^。,，！…；~？]*(?:回购|买返|买入返售)',coo)
             zhaop2= re.search('(?:收)[^。,，！…；~？]*(?:回购|买返|买入返售)[^。,，！…；~]*(?:吗|么|找|联系|？)',coo)
             if zhaop or zhaop1 or zhaop2:
                  chuhui='1'

                  guanggao=guanggao+'出回购'


             zhaop= re.search('^((?!(谁|有人)).)*(?:出)[^。,，！…；~？]*(?:代持)((?!(吗|么|找|联系|？)).)*$',coo)
             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:收)[^。,，！…；~？]*(?:代持)',coo)
             zhaop2= re.search('(?:收)[^。,，！…；~？]*(?:代持)[^。,，！…；~]*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2:
              chudai='1'
              guanggao=guanggao+'出代持'

         
             zhaop= re.search('^((?!(谁|有人)).)*(?:出|卖)[^。,，！…；~？]*(?:票|电银|足月|足年|\d月|农商|国股|城商)((?!(买返|买入返售|回购|代持|吗|么|找|联系|？)).)*$',coo)
             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:收|买)[^。,，！…；~？]*(?:票|电银|足月|足年|\d月|农商|国股|城商)((?!(买返|买入返售|回购|代持)).)*$',coo)
             zhaop2= re.search('(?:收|买)[^。,，！…；~？]*(?:票|电银|足月|足年|\d月|农商|国股|城商)[^。,，！…；~？]*((?!(买返|买入返售|回购|代持|。|,|，|！|…|；|~)).)*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2:
                 chu='1'

                 guanggao=guanggao+'出票'



#二、福费廷广告

             zhaop= re.search('^((?!(谁|有人)).)*(?:收|买)[^。,，！…；~？]*(?:福费廷|信用证)((?!(吗|么|找|联系|？)).)*$',coo)

             zhaopd= re.search('^((?!(谁|有人)).)*(?:收证)((?!(吗|么|找|联系|？)).)*$',coo)


             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:出|卖)[^。,，！…；~？]*(?:福费廷|信用证)',coo)
             zhaopd1= re.search('(?:谁|有人)[^。,，！…；~]*(?:出证)',coo)
 
             zhaop2= re.search('(?:出|卖)[^。,，！…；~？]*(?:福费廷|信用证)[^。,，！…；~？]*((?!(。|,|，|！|…|；|~)).)*(?:吗|么|找|联系|？)',coo)
             zhaopd2= re.search('(?:出证)[^。,，！…；~]*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2 or zhaopd2 or zhaopd1 or zhaopd :
                 shoufu='1'
                 guanggao=guanggao+'收证'



             zhaop= re.search('^((?!(谁|有人)).)*(?:出|卖)[^。,，！…；~？]*(?:福费廷|信用证)((?!(吗|么|找|联系|？)).)*$',coo)

             zhaopd= re.search('^((?!(谁|有人)).)*(?:出证)((?!(吗|么|找|联系|？)).)*$',coo)


             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:收|买)[^。,，！…；~？]*(?:福费廷|信用证)',coo)
             zhaopd1= re.search('(?:谁|有人)[^。,，！…；~]*(?:收证)',coo)
 
             zhaop2= re.search('(?:收|买)[^。,，！…；~？]*(?:福费廷|信用证)[^。,，！…；~？]*((?!(。|,|，|！|…|；|~)).)*(?:吗|么|找|联系|？)',coo)
             zhaopd2= re.search('(?:收证)[^。,，！…；~]*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2 or zhaopd2 or zhaopd1 or zhaopd :
                 chufu='1'
                 guanggao=guanggao+'出证'



#三、理财广告

             zhaop= re.search('^((?!(谁|有人)).)*(?:收|买|投)[^。,，！…；~？]*(?:理财)((?!(吗|么|找|联系|？)).)*$',coo)
             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:出|发|卖)[^。,，！…；~？]*(?:理财)',coo)
 
             zhaop2= re.search('(?:出|卖|发)[^。,，！…；~？]*(?:理财)[^。,，！…；~？]*((?!(。|,|，|！|…|；|~)).)*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2  :
                 shouli='1'
                 guanggao=guanggao+'收理财'



             zhaop= re.search('^((?!(谁|有人)).)*(?:出|卖|发)[^。,，！…；~？]*(?:理财)((?!(吗|么|找|联系|？)).)*$',coo)
             zhaopd= re.search('(?:理财)[^。,，！…；~？]*(?:价|：|:)',coo)



             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:收|买|投)[^。,，！…；~？]*(?:理财)',coo)
 
             zhaop2= re.search('(?:收|买|投)[^。,，！…；~？]*(?:理财)[^。,，！…；~？]*((?!(。|,|，|！|…|；|~)).)*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2 or zhaopd :
                 chuli='1'
                 guanggao=guanggao+'出理财'




#四、存单广告


             zhaop= re.search('^((?!(谁|有人)).)*(?:收|买|投)[^。,，！…；~？]*(?:存单|NCD|ncd|资金)((?!(吗|么|找|联系|？)).)*$',coo)



             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:出|发|卖)[^。,，！…；~？]*(?:存单|NCD|ncd|资金)',coo)
 
             zhaop2= re.search('(?:出|卖|发)[^。,，！…；~？]*(?:存单|NCD|ncd|资金)[^。,，！…；~？]*((?!(。|,|，|！|…|；|~)).)*(?:吗|么|找|联系|？)',coo)

             if zhaop or zhaop1 or zhaop2  :
                 shoucun='1'
                 guanggao=guanggao+'收存单'



             zhaop= re.search('^((?!(谁|有人)).)*(?:出|卖|发)[^。,，！…；~？]*(?:存单|NCD|ncd|资金)((?!(吗|么|找|联系|？)).)*$',coo)
             zhaop1= re.search('(?:谁|有人)[^。,，！…；~？]*(?:收|买|投)[^。,，！…；~？]*(?:存单|NCD|ncd|资金)',coo)
             zhaop2= re.search('(?:收|买|投)[^。,，！…；~？]*(?:存单|NCD|ncd|资金)[^。,，！…；~？]*((?!(。|,|，|！|…|；|~)).)*(?:吗|么|找|联系|？)',coo)
             zhaopd= re.search('(?:存单|NCD|ncd|资金)[^。,，！…；~？]*(?:价|：|:)',coo)

             if zhaop or zhaop1 or zhaop2 or zhaopd :
                 chucun='1'
                 guanggao=guanggao+'出存单'





             if (int(shou)+int(chu)+int(shouhui)+int(chuhui)+int(shoudai)+int(chudai)+int(shoufu)+int(chufu)+int(shoucun)+int(chucun)+int(shouli)+int(chuli))!=0:

         #  name=co.sub(u'',msg['ActualNickName'])


               if name in dict_nickname:
                   hanglei1=dict_nickname.get(name)[0]
                   hanglei2=dict_nickname.get(name)[1]
                   hanglei3=dict_nickname.get(name)[2]
                   killci=name
               if killci=='':  
                 for j2 in range(0,len(shan_df1)):
                    if shan_df1.loc[j2,'yinhang'] in (name): 
                       hanglei1=shan_df1.astype(str).loc[j2,'fenlei1'].strip()
                       hanglei2=str(shan_df1.astype(str).loc[j2,'fenlei2'].strip())
                       hanglei3=str(shan_df1.astype(str).loc[j2,'fenlei3'].strip())
                    #   killci=shan_df1.loc[j2,'yinhang']
                       break
                    else:
                       for j2 in range(0,len(shan_df2)): 
                          if shan_df2.loc[j2,'yinhang'] in string[num-1]:
                           hanglei1=shan_df2.astype(str).loc[j2,'fenlei1'].strip()
                           hanglei2=str(shan_df2.astype(str).loc[j2,'fenlei2'].strip())
                           hanglei3=str(shan_df2.astype(str).loc[j2,'fenlei3'].strip())
                       #    killci=shan_df2.loc[j2,'yinhang']
                           break
                          else:
                            if num-2>=0:
                                if shan_df2.loc[j2,'yinhang'] in string[num-2]:
                                     hanglei1=shan_df2.astype(str).loc[j2,'fenlei1'].strip()
                                     hanglei2=str(shan_df2.astype(str).loc[j2,'fenlei2'].strip())
                                     hanglei3=str(shan_df2.astype(str).loc[j2,'fenlei3'].strip())
                                 #    killci=shan_df2.loc[j2,'yinhang']
                                     break
                                else:
                                                 if shan_df2.loc[j2,'yinhang'] in string[0]:
                                                         hanglei1=shan_df2.astype(str).loc[j2,'fenlei1'].strip()
                                                         hanglei2=str(shan_df2.astype(str).loc[j2,'fenlei2'].strip())
                                                         hanglei3=str(shan_df2.astype(str).loc[j2,'fenlei3'].strip())
                                                   #      killci=shan_df2.loc[j2,'yinhang']
                                                         break
               shijian1=time.strftime('%Y-%m-%d',time.localtime(time.time()))
               shijian2=time.strftime('%H:%M',time.localtime(time.time()))
               clr.print_blue_text('群广告：%s    时间：%s'%(guanggao,shijian2))
               clr.print_blue_text ('机构类型：%s'%hanglei1),
               clr.print_blue_text("来源：%s"%qunming2),
               clr.print_blue_text ('昵称：%s'%name2)      #输出在本群的昵称？还是自己的备注名？
               clr.print_blue_text("内容：%s"%coo)
               clr.print_blue_text('\n')

               url = url0+'103?time='+urllib.parse.quote(shijian1)+\
                      '&time2='+urllib.parse.quote(shijian2)+\
                              '&hanglei2='+urllib.parse.quote(str(hanglei2))+\
                              '&hanglei3='+urllib.parse.quote(str(hanglei3))+\
                              '&hanglei1='+urllib.parse.quote(str(hanglei1))+\
                              '&nickname='+urllib.parse.quote(name)+\
                              '&shou='+urllib.parse.quote(str(shou))+\
                              '&chu='+urllib.parse.quote(str(chu))+\
                              '&shoudai='+urllib.parse.quote(str(shoudai))+\
                              '&chudai='+urllib.parse.quote(str(chudai))+\
                              '&shouhui='+urllib.parse.quote(str(shouhui))+\
                              '&chuhui='+urllib.parse.quote(str(chuhui))+\
                              '&shoufu='+urllib.parse.quote(str(shoufu))+\
                              '&chufu='+urllib.parse.quote(str(chufu))+\
                              '&shouli='+urllib.parse.quote(str(shouli))+\
                              '&chuli='+urllib.parse.quote(str(chuli))+\
                              '&shoucun='+urllib.parse.quote(str(shoucun))+\
                              '&chucun='+urllib.parse.quote(str(chucun))+\
                              '&content='+urllib.parse.quote(cooo)+\
                              '&leixing='+urllib.parse.quote(username2)
                        #      '&killci='+killci+\
                           #   '&qun='+chatrooms1['NickName']


               for tries in range(maxTryNum):
                try:
                    res_data = urllib.request.urlopen(url,timeout=15)
                    break
                except:
                    if tries < (maxTryNum - 1):
                    #print(tries)
                        continue
                    else:
                        aaa=("您的网络较差，无法连接\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")
                 # #  leb2.config(text=aaa,justify = 'left')  #左对齐
                        break

           






#一、单独回复
@itchat.msg_register([TEXT])  
def text_reply(msg):
      co=re.compile(u'[\U00010000-\U0010ffff]')

      friend=itchat.search_friends(userName=msg['FromUserName'])
      friend2=co.sub(u'',friend['NickName'])
      remarkname=co.sub(u'',str(friend['RemarkName']))

      
      shijian=time.strftime('%Y-%m-%d %H:%M:%S',time.localtime(time.time()))
      shijian1=time.strftime('%H:%M:%S',time.localtime(time.time()))
      shijian2=time.strftime('%Y-%m-%d',time.localtime(time.time()))

      print('私信：')


      print ("%s  %s(%s):"%(shijian,friend2,remarkname))
    #print msg['FromUserName']
      content2=co.sub(u'',msg['Content'])

      print (content2)

      zong1=pd.DataFrame({'发送人': ['%s(%s)'%(friend2,remarkname)],
                                '时间': [shijian1],
                                '内容': [content2],
                                '日期': [shijian2]
                         })

      mychat=input('回复内容（暂不回复可按回车）:')
      #print friend
      print ("我：%s"%mychat)
      print('\n')
      
      shijian1=time.strftime('%H:%M:%S',time.localtime(time.time()))
      shijian2=time.strftime('%Y-%m-%d',time.localtime(time.time()))
      zong2=pd.DataFrame({'发送至': ['%s(%s)'%(friend2,remarkname)],
                                '时间': [shijian1],
                                '内容': [mychat],
                                '日期': [shijian2]
                         })


      zong=pd.concat([zong1,zong2])
      zong= zong.reset_index(drop=True)    #重新定义索引
      zong.to_csv('sixin.csv',encoding='GB18030',mode='a',header=False)

      return (mychat)
    





  












     
class MyCollectApp2(tk.Toplevel):#重点
    def __init__(self):
        super().__init__() #重点
        self.title('会员登录')
        self.setupUI()

    def setupUI(self):
        row1 = tk.Frame(self)
        row1.pack(fill="x")
        l1 = tk.Label(row1, text="用户名：",height=2,width=10)
        l1.pack(side=tk.LEFT)  # 这里的side可以赋值为LEFT  RTGHT TOP  BOTTOM
        self.xls_text = tk.StringVar()
        tk.Entry(row1, textvariable=self.xls_text).pack(side=tk.RIGHT)

        row2 = tk.Frame(self)
        row2.pack(fill="x")
        l1 = tk.Label(row2, text="密码：",height=2,width=10)
        l1.pack(side=tk.LEFT)  # 这里的side可以赋值为LEFT  RTGHT TOP  BOTTOM
        self.xls_text2 = tk.StringVar()
        tk.Entry(row2, textvariable=self.xls_text2).pack(side=tk.RIGHT)







        row5 = tk.Frame(self)
        row5.pack(fill="x")
      #  UserName = self.xls_text.get().lstrip()

        tk.Button(row5, text="点击确认", command=self.piao2).pack(side=tk.RIGHT)






    def piao2(self):
        global url0,password0,username2,a1,bufa,root,dict_nickname,shan_df1,shan_df2,yaokan,yaokan2
        font_set = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=15) #用于在散点图中输出中文
        maxTryNum=5
        username2 = self.xls_text.get().lstrip()
        password0 = self.xls_text2.get().lstrip()

        print(username2)
        print(password0)



        co=re.compile(u'[\U00010000-\U0010ffff]')


        if os.path.exists('非业务群（消息全部显示）.xls'):
            
            qunming2=pd.read_excel('非业务群（消息全部显示）.xls',encoding='GB18030')
            qunming2=qunming2.reset_index(drop = False)




            for i in range(0,len(qunming2)):
              qunming2.loc[i,'群名']= co.sub(u'',qunming2.loc[i,'群名'])
            yaokan=qunming2[qunming2['定义']=='全名']
            yaokan=yaokan['群名'].tolist()
            yaokan2=qunming2[qunming2['定义']=='关键词']
            yaokan2=yaokan2['群名'].tolist()
        else:
             yaokan=[]
             yaokan2=[]





#一、到日所需数据库
      #  url0='http://www.51tradecloud.com/'



        password = urllib.request.HTTPPasswordMgrWithDefaultRealm()
        password.add_password(None,url0,username2,password0)
        handler=urllib.request.HTTPBasicAuthHandler(password)
        opener = urllib.request.build_opener(handler)  
        urllib.request.install_opener(opener)


        url = url0+'101'
        for tries in range(maxTryNum):
            try:
                res_data = urllib.request.urlopen(url,timeout=15)
                break
            except:
                if tries < (maxTryNum - 1):
                    print(tries)
                    continue
                else:
                    self.destroy()
                    tk.messagebox.showinfo(message="网络较差，未能登录")


                    return
        res = res_data.read()
        shan=res.decode('utf-8')
        shan_df= pd.read_json(shan,typ='frame')  #方法二
        shan_df=shan_df[['xuhao','yinhang','fenlei1','fenlei2','fenlei3','过滤']]
        shan_df1=shan_df[shan_df['过滤']>=1]
        shan_df1= shan_df1.reset_index(drop=True)    #重新定义索引
        shan_df2=shan_df[shan_df['过滤']>=2]
        shan_df2= shan_df2.reset_index(drop=True)    #重新定义索引


        url = url0+'102'
        for tries in range(maxTryNum):
            try:
                res_data = urllib.request.urlopen(url,timeout=15)
                break
            except:
                if tries < (maxTryNum - 1):
                    print(tries)
                    continue
                else:
                    self.destroy()
                    tk.messagebox.showinfo(message="网络较差，未能登录")

                    return
        res = res_data.read()
        nickname_df=res.decode('utf-8')
        nickname_df= pd.read_json(nickname_df,typ='frame')  #方法二

        dict_nickname = nickname_df.set_index('nickname').T.to_dict('list')
        self.destroy()


  
        itchat.auto_login(hotReload=True)

        tk.messagebox.showinfo(message="登录成功！消息会在CMD窗口显示")


        
        itchat.run()








 



def piao():
    global username2,password0,root2
    root = Tk()
    root.withdraw() #****实现主窗口隐藏  
    var_box = tk.messagebox.askyesno(title='是否继续',message='请扫描即将弹出的二维码或在手机微信上确认，登录完毕后，请在CMD窗口（黑框）监控微信群消息。')#返回'True','False'

    if var_box:
        app = MyCollectApp2()
        app.mainloop()



piao()
# Out:
# 189

# %% [markdown]
# # 再贴现分数

# %%
import csv,xlrd,xlwt,datetime,time,re
import numpy as np

import pandas as pd




#一、导入指导价

#二、打开对方清单
def zaitiexian():
    global df
    df=pd.read_excel('计算分数\再贴现分数统计.xlsx',encoding='GB18030')
    
    for i in range(0,len(df)):
        if df.loc[i,'2018年上半年']==0:
            df.loc[i,'2018年上半年排名']=999
        if df.loc[i,'2018年下半年']==0:
            df.loc[i,'2018年下半年排名']=999
        if df.loc[i,'2019年上半年']==0:
            df.loc[i,'2019年上半年排名']=999 
    
    df['2019年上半年再贴现发生量得分']=df['2019年上半年排名'].replace(1000,10).replace(999,0).replace(8,800).replace(1,10).replace(2,10).replace(3,8).replace(4,8).replace(5,6).replace(7,6).replace(800,4).replace(9,4).replace(1000,4)
    df['2018年下半年再贴现发生量得分']=df['2018年下半年排名'].replace(1000,10).replace(999,0).replace(8,800).replace(1,10).replace(2,10).replace(3,8).replace(4,8).replace(5,6).replace(7,6).replace(800,4).replace(9,4).replace(1000,4)
    df['2018年上半年再贴现发生量得分']=df['2018年上半年排名'].replace(1000,10).replace(999,0).replace(8,800).replace(1,10).replace(2,10).replace(3,8).replace(4,8).replace(5,6).replace(7,6).replace(800,4).replace(9,4).replace(1000,4)

    

    
    
    df['2019年上半年再贴现发生量环比增长率']=(df['2019年上半年']-df['2018年下半年'])/df['2018年下半年']
    df['2018年下半年再贴现发生量环比增长率']=(df['2018年下半年']-df['2018年上半年'])/df['2018年上半年']

    df= df.reset_index(drop=False)    #重新定义索引

    
    for i in range(0,len(df)):
        if df.loc[i,'2019年上半年再贴现发生量环比增长率']>0.02:
            df.loc[i,'2019年上半年再贴现发生量环比增长率得分']=2
        elif df.loc[i,'2019年上半年再贴现发生量环比增长率']< 0:
            df.loc[i,'2019年上半年再贴现发生量环比增长率得分']=0
        else:
            df.loc[i,'2019年上半年再贴现发生量环比增长率得分']=0
            
  
    
    for i in range(0,len(df)):
        if df.loc[i,'2018年下半年再贴现发生量环比增长率']>0.02:
            df.loc[i,'2018年下半年再贴现发生量环比增长率得分']=2
        elif df.loc[i,'2018年下半年再贴现发生量环比增长率']< 0:
            df.loc[i,'2018年下半年再贴现发生量环比增长率得分']=0
        else:
            df.loc[i,'2018年下半年再贴现发生量环比增长率得分']=0
            
  
    df=df.set_index(['交易机构'])
    df['来源']='经营报表'

    df.to_excel('再贴现分数.xls')



    
    
    
    
zaitiexian()

# %% [markdown]
# # 利润得分

# %%
import csv,xlrd,xlwt,datetime,time,re
import numpy as np

import pandas as pd




#一、导入指导价

#二、打开对方清单
def zaitiexian():
    global lirun
    df=pd.read_excel('计算分数/2018年12月银行自营收入统计表考核口径（20190109）2.xls',encoding='GB18030')
    df=df[['地区','市县','（一）票据直贴收入','1.票据转贴收入','银行自营收入']]
    df=df.fillna(method='ffill')  #用缺失值前面的数字填充缺失值
    df=df[df['市县']=='小计']
    df['2018年全年利润']=df['（一）票据直贴收入']+df['1.票据转贴收入']
    df=df.set_index(['地区'])
    df.rename(columns={'银行自营收入':'2018年全年银行自营收入'}, inplace=True)

    
    df=df[['2018年全年利润','2018年全年银行自营收入']]  #########################


    
    df2=pd.read_excel('计算分数/2018年6月银行自营收入统计表.xls','累计',encoding='GB18030')
    df2=df2[['地区','市县','（一）票据直贴收入','1.票据转贴收入','银行自营收入']]
    df2=df2.fillna(method='ffill')  #用缺失值前面的数字填充缺失值
    df2=df2[df2['市县']=='小计']
    df2['2018年上半年利润']=df2['（一）票据直贴收入']+df2['1.票据转贴收入']

    df2=df2.set_index(['地区'])
    df2.rename(columns={'银行自营收入':'2018年上半年银行自营收入'}, inplace=True)
    df2=df2[['2018年上半年利润','2018年上半年银行自营收入']]

 
    df3=pd.read_excel('计算分数/55.xls','累计',encoding='GB18030')
    df3=df3[['地区','市县','（一）票据直贴收入','1.票据转贴收入','银行自营收入']]
    df3=df3.fillna(method='ffill')  #用缺失值前面的数字填充缺失值
    df3=df3[df3['市县']=='小计']
    df3['2019年上半年利润']=df3['（一）票据直贴收入']+df3['1.票据转贴收入']
    df3=df3.set_index(['地区'])
    df3.rename(columns={'银行自营收入':'2019年上半年银行自营收入'}, inplace=True)

    df3=df3[['2019年上半年利润','2019年上半年银行自营收入']]

    lirun=pd.concat([df,df2,df3], axis=1)  
    lirun['2018年下半年利润']=lirun['2018年全年利润']-lirun['2018年上半年利润']
    lirun['2018年下半年银行自营收入']=lirun['2018年全年银行自营收入']-lirun['2018年上半年银行自营收入']


    lirun['2018上半年利润排名']=lirun['2018年上半年利润'].rank(ascending=False).astype('int')
    lirun['2018下半年利润排名']=lirun['2018年下半年利润'].rank(ascending=False).astype('int')
    lirun['2019上半年利润排名']=lirun['2019年上半年利润'].rank(ascending=False).astype('int')
    
    
    
    lirun['2018年上半年银行自营收入排名']=lirun['2018年上半年银行自营收入'].rank(ascending=False).astype('int')
    lirun['2018年下半年银行自营收入排名']=lirun['2018年下半年银行自营收入'].rank(ascending=False).astype('int')
    lirun['2019年上半年银行自营收入排名']=lirun['2019年上半年银行自营收入'].rank(ascending=False).astype('int')
       
    lirun['2018年上半年排名相减']=lirun['2018上半年利润排名']-lirun['2018年上半年银行自营收入排名']
    lirun['2018年下半年排名相减']=lirun['2018下半年利润排名']-lirun['2018年下半年银行自营收入排名']
    lirun['2019年上半年排名相减']=lirun['2019上半年利润排名']-lirun['2019年上半年银行自营收入排名']
    

    
    lirun['2019上半年利润排名得分']=lirun['2019上半年利润排名'].replace(10,1000).replace(1,25).replace(2,21).replace(3,17).replace(4,13).replace(5,10).replace(6,10).replace(7,10).replace(8,10).replace(9,8).replace(1000,8)
    lirun['2018上半年利润排名得分']=lirun['2018上半年利润排名'].replace(10,1000).replace(1,25).replace(2,21).replace(3,17).replace(4,13).replace(5,10).replace(6,10).replace(7,10).replace(8,10).replace(9,8).replace(1000,8)
    lirun['2018下半年利润排名得分']=lirun['2018下半年利润排名'].replace(10,1000).replace(1,25).replace(2,21).replace(3,17).replace(4,13).replace(5,10).replace(6,10).replace(7,10).replace(8,10).replace(9,8).replace(1000,8)



    
    
    lirun['2019上半年利润环比增长率']=(lirun['2019年上半年利润']-lirun['2018年下半年利润'])/lirun['2018年下半年利润']
    lirun['2018下半年利润环比增长率']=(lirun['2018年下半年利润']-lirun['2018年上半年利润'])/lirun['2018年上半年利润']

    
    
    lirun= lirun.reset_index(drop=False)    #重新定义索引

    
    for i in range(0,len(lirun)):
        if lirun.loc[i,'2019上半年利润环比增长率']>0.03:
            lirun.loc[i,'2019上半年利润环比增长率得分']=3
        elif lirun.loc[i,'2019上半年利润环比增长率']<0:
            lirun.loc[i,'2019上半年利润环比增长率得分']=0
        else:
            lirun.loc[i,'2019上半年利润环比增长率得分']=0
            
    for i in range(0,len(lirun)):
        if lirun.loc[i,'2018下半年利润环比增长率']>0.03:
            lirun.loc[i,'2018下半年利润环比增长率得分']=3
        elif lirun.loc[i,'2018下半年利润环比增长率']< 0:
            lirun.loc[i,'2018下半年利润环比增长率得分']=0
        else:
            lirun.loc[i,'2018下半年利润环比增长率得分']=0

            

    for i in range(0,len(lirun)):
        if lirun.loc[i,'2018年上半年排名相减']>=3:
           lirun.loc[i,'2018年上半年排名相减得分']=0
        elif lirun.loc[i,'2018年上半年排名相减']<=-3:
           lirun.loc[i,'2018年上半年排名相减得分']=3
        else:
           lirun.loc[i,'2018年上半年排名相减得分']=0
        
    for i in range(0,len(lirun)):
        if lirun.loc[i,'2018年下半年排名相减']>=3:
           lirun.loc[i,'2018年下半年排名相减得分']=0
        elif lirun.loc[i,'2018年下半年排名相减']<=-3:
           lirun.loc[i,'2018年下半年排名相减得分']=3
        else:
           lirun.loc[i,'2018年下半年排名相减得分']=0
        
    for i in range(0,len(lirun)):
        lirun.loc[i,'地区']= lirun.loc[i,'地区'].replace('地区','市分行')
        if lirun.loc[i,'2019年上半年排名相减']>=3:
           lirun.loc[i,'2019年上半年排名相减得分']=0
        elif lirun.loc[i,'2019年上半年排名相减']<=-3:
           lirun.loc[i,'2019年上半年排名相减得分']=3
        else:
           lirun.loc[i,'2019年上半年排名相减得分']=0    
        
        
        
        
        
    lirun.to_excel('利润分数.xls')
    lirun['来源']='计财数据'
    lirun=lirun.set_index(['地区'])

zaitiexian()

# %% [markdown]
# # 汇总

# %%
zong=pd.concat([zongfen,df,lirun], axis=1)  
zong.to_excel('预测分数总.xls')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %% [markdown]
# # 省行转贴现的利润表分析

# %%
import csv,xlrd,xlwt,datetime,time,re
import numpy as np

import pandas as pd




#一、导入指导价

#二、打开对方清单
def zaitiexian():
    global lirun
    df=pd.read_excel('计算分数/2018年12月银行自营收入统计表考核口径（20190109）2.xls',encoding='GB18030')
    df=df[['地区','1.票据转贴收入']]
    df=df[df['地区']=='省分行']
    df=df.set_index(['地区'])
    df.rename(columns={'1.票据转贴收入':'2018年全年利润'}, inplace=True)


    
    df2=pd.read_excel('计算分数/2018年6月银行自营收入统计表.xls','累计',encoding='GB18030')
    df2=df2[['地区','1.票据转贴收入']]
    df2=df2[df2['地区']=='省分行']
    df2=df2.set_index(['地区'])
    df2.rename(columns={'1.票据转贴收入':'2018年上半年利润'}, inplace=True)


    

 
    df3=pd.read_excel('计算分数/55.xls','6月',encoding='GB18030')
    df3=df3[['地区','市县','（一）票据直贴收入','1.票据转贴收入']]
    df3=df3[df3['市县']=='小计']
    df3['2018年全年利润']=df3['（一）票据直贴收入']+df3['1.票据转贴收入']

    #df3=df3.set_index(['地区'])
    df3.rename(columns={'1.票据转贴收入':'2019年6月利润'}, inplace=True)

    df3.to_excel('6月转贴利润.xls')
    stop
    
    
    lirun=pd.concat([df,df2,df3], axis=1)  
    lirun['2018年下半年利润']=lirun['2018年全年利润']-lirun['2018年上半年利润']


    
    
    lirun['2019上半年利润环比增长率']=(lirun['2019年上半年利润']-lirun['2018年下半年利润'])/lirun['2018年下半年利润']
    lirun['2018下半年利润环比增长率']=(lirun['2018年下半年利润']-lirun['2018年上半年利润'])/lirun['2018年上半年利润']

    
    
    lirun= lirun.reset_index(drop=False)    #重新定义索引

    
 
        
        
    lirun['来源']='计财数据'
    lirun=lirun.set_index(['地区'])
    lirun.to_excel('转贴利润.xls')

zaitiexian()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0e2dd6b9bcb2> in <module>()
#      63     lirun.to_excel('转贴利润.xls')
#      64
# ---> 65 zaitiexian()
#
# <ipython-input-5-0e2dd6b9bcb2> in zaitiexian()
#      39
#      40     df3.to_excel('6月转贴利润.xls')
# ---> 41     stop
#      42
#      43
#
# NameError: name 'stop' is not defined
