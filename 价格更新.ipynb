# %% [markdown]
# # 1.价格更新

# %%
import csv,xlrd,xlwt,datetime,time
import pandas as pd





#一、导入指导价
jia_df=pd.read_excel('转贴现买断价格计算/jia.xls',encoding='GB18030')
jiage=pd.read_excel('转贴现买断价格计算/价格更新/jiage.xls',encoding='GB18030')


jiagecolumn=jiage.columns.values.tolist()[1:]  
jia_dfcolumn=jia_df.columns.values.tolist()[2:7]  

print(jiagecolumn)
print(jia_dfcolumn)

jia_df.columns=['银行类型','银行分类']+jiagecolumn+['授信有效','可用额度','生效截至日','我行评级','更新日期','特殊报价']



#for i in range(0,len(jiagecolumn)):
#     print(i)
#     print(jia_dfcolumn[i])
#     print(jiagecolumn[i])
        
        
#     jia_df.rename(columns={jia_dfcolumn[i]:jiagecolumn[i]}, inplace=True)
#     print(jia_df.head())

print(jia_df)
for i in range(0,len(jia_df)):
  for j in range(0,len(jiage)):
    
    if (jiage.loc[j,'银行分类'] ==jia_df.loc[i,'银行类型']):
       jia_df.loc[i,jia_df.columns[2]]=jiage.loc[j,jiage.columns[1]]
       jia_df.loc[i,jia_df.columns[3]]=jiage.loc[j,jiage.columns[2]]
       jia_df.loc[i,jia_df.columns[4]]=jiage.loc[j,jiage.columns[3]]
       jia_df.loc[i,jia_df.columns[5]]=jiage.loc[j,jiage.columns[4]]
       jia_df.loc[i,jia_df.columns[6]]=jiage.loc[j,jiage.columns[5]]
       jia_df.loc[i,'特殊报价']= '1'
       
       break
    else:
      if  (jia_df.loc[i,'银行分类']==jiage.loc[j,'银行分类']):
               jia_df.loc[i,jia_df.columns[2]]=jiage.loc[j,jiage.columns[1]]
               jia_df.loc[i,jia_df.columns[3]]=jiage.loc[j,jiage.columns[2]]
               jia_df.loc[i,jia_df.columns[4]]=jiage.loc[j,jiage.columns[3]]
               jia_df.loc[i,jia_df.columns[5]]=jiage.loc[j,jiage.columns[4]]
               jia_df.loc[i,jia_df.columns[6]]=jiage.loc[j,jiage.columns[5]]
              # print(str(jia_df.loc[i,'我行评级']))
               break
      else:
               jia_df.loc[i,jia_df.columns[2]]=0
               jia_df.loc[i,jia_df.columns[3]]=0
               jia_df.loc[i,jia_df.columns[4]]=0
               jia_df.loc[i,jia_df.columns[5]]=0
               jia_df.loc[i,jia_df.columns[6]]=0
              # print(str(jia_df.loc[i,'我行评级']))
            #   break

jia_df=jia_df.set_index('银行类型')       
url3='转贴现买断价格计算/jia-价格.xls'
writer = pd.ExcelWriter(url3)
jia_df.to_excel(writer,'Sheet1')
writer.save()
# Out:
# ['2019-09-01至2019-09-30', '2019-11-01至2019-12-30', '2020-01-01至2020-02-29', '2020-03-01至2020-05-31', '2020-06-01至2020-12-30']
# ['2019-01-01至2019-03-29', '2019-11-01至2019-12-29', '2020-02-01至2020-03-31', '2020-04-01至2020-05-31', '2020-06-01至2020-12-30']
#              银行类型              银行分类  2019-09-01至2019-09-30  \
# 0          浦东发展银行         国股（授信银行贴）                   0.00
# 1              浦发         国股（授信银行贴）                   0.00
# 2            兴业银行         国股（授信银行贴）                   0.00
# 3            华夏银行         国股（授信银行贴）                   0.00
# 4            工商银行         国股（授信银行贴）                   0.00
# 5            农业银行         国股（授信银行贴）                   0.00
# 6          农业发展银行         国股（授信银行贴）                   0.00
# 7            中国银行         国股（授信银行贴）                   0.00
# 8            建设银行         国股（授信银行贴）                   0.00
# 22                    3.35   有效  5.169793e+09           2019-11-12    AA
# 23                    3.35   有效  2.835730e+09           2019-10-18    AA
# 24                    3.35   有效  7.262350e+04           2019-08-12   AA-
# 25                    3.35   有效  9.659778e+08           2019-09-20   AA-
# 26                    3.35   有效  1.854153e+05           2019-08-27    AA
# 27                    3.40   有效  7.344446e+05           2019-08-12     A
# 28                    3.40   有效  4.403999e+09           2019-06-27   AA-
# 29                    3.40   有效  3.275650e+07           2019-09-18   AA-
# ..                     ...  ...           ...                  ...   ...
# 530                   0.00   有效           NaN           2019-07-01    A-
# 531                   0.00   有效           NaN           2019-08-07     A
# 532                   0.00   有效           NaN           2019-09-11   BBB
# 533                   0.00   有效           NaN           2019-06-04    A-
# 534                   0.00   有效           NaN           2019-12-02  BBB+
# 535                   0.00   有效           NaN           2019-08-28   BBB
# 536                   3.60   有效           NaN           2019-12-23   BBB
# 537                   3.60   有效           NaN           2019-12-26    A-
# 538                   3.60   有效           NaN           2019-12-26   BBB
# 539                   0.00   有效           NaN           2019-09-11     A
# 540                   3.60   有效           NaN           2019-09-16    A-
# 541                   3.60   有效           NaN           2020-01-07     A
# 542                   0.00   失效           NaN           2019-04-28   BBB
# 543                   0.00   有效           NaN           2019-10-18   BBB
# 544                   0.00   有效           NaN           2019-06-18    A+
# 545                   3.60   有效           NaN           2020-03-10    A+
# 546                   3.60   有效           NaN           2020-03-07  BBB+
# 547                   3.60   有效           NaN           2020-02-17  BBB-
# 548                   3.60   有效           NaN           2019-09-30   AA-
# 549                   3.60   有效           NaN           2020-03-25    A-
# 550                   3.60   有效           NaN           2019-06-30     A
# 551                   0.00   有效           NaN           2019-08-15    A+
# 552                   3.60   有效           NaN           2019-07-22    A+
# 553                   3.60   有效           NaN           2019-08-30  BBB+
# 554                   3.35  NaN           NaN                  NaN   NaN
# 555                   3.40  NaN           NaN                  NaN   NaN
# 556                   3.65  NaN           NaN                  NaN   NaN
# 557                   3.70  NaN           NaN                  NaN   NaN
# 558                   3.60  NaN           NaN                  NaN   NaN
# 559                   3.70  NaN           NaN                  NaN   NaN
#
#            更新日期  特殊报价
# 0           NaN   NaN
# 1           NaN   NaN
# 2           NaN   NaN
# 3           NaN   NaN
# 4           NaN   NaN
# 5           NaN   NaN
# 6           NaN   NaN
# 7    2019-05-27   NaN
# 8           NaN   NaN
# 9           NaN   NaN
# 10          NaN   NaN
# 11          NaN   NaN
# 12          NaN   NaN
# 13          NaN   NaN
# 14          NaN   NaN
# 15          NaN   NaN
# 16          NaN   NaN
# 17          NaN   NaN
# 18          NaN   NaN
# 19          NaN   NaN
# 20          NaN   NaN
# 21          NaN   NaN
# 22          NaN   NaN
# 23          NaN   NaN
# 24          NaN   NaN
# 25          NaN   NaN
# 26          NaN   NaN
# 27          NaN   NaN
# 28          NaN   NaN
# 29          NaN   NaN
# ..          ...   ...
# 530         NaN   NaN
# 531         NaN   NaN
# 532         NaN   NaN
# 533         NaN   NaN
# 534         NaN   NaN
# 535         NaN   NaN
# 536         NaN   NaN
# 537         NaN   NaN
# 538         NaN   NaN
# 539         NaN   NaN
# 540         NaN   NaN
# 541         NaN   NaN
# 542    20190513   NaN
# 543         NaN   NaN
# 544         NaN   NaN
# 545         NaN   NaN
# 546         NaN   NaN
# 547         NaN   NaN
# 548         NaN   NaN
# 549         NaN   NaN
# 550         NaN   NaN
# 551         NaN   NaN
# 552         NaN   NaN
# 553         NaN   NaN
# 554         NaN   NaN
# 555         NaN   NaN
# 556         NaN   NaN
# 557         NaN   NaN
# 558         NaN   NaN
# 559         NaN   NaN
#
# [560 rows x 13 columns]

# %% [markdown]
# # 信贷评级更新

# %%
import csv,xlrd,xlwt,datetime,time
import pandas as pd





riqi=input('请输入要最新授信表的日期:')
url=input('请输入要最新授信表的文件名（包括后缀）:')

shouxin=pd.read_excel('C:/Users/yangbing/gitskills/转贴现买断价格计算/评级更新/%s'%url,sheetname=1,encoding='GB18030')


shouxin=shouxin[['客户名称','客户状态','额度到期日','本年度信用评级']]

shouxin['d']=0
am=['A-','A','A+','AA-','AA','AA+','AAA-','AAA','AAA+']
bbb=['BBB+']

shouxin= shouxin.reset_index(drop=True)    #重新定义索引


#一、导入指导价
jia_df=pd.read_excel('C:/Users/yangbing/gitskills/转贴现买断价格计算/jia.xls',encoding='GB18030')
#jia_df=pd.read_table('jia2.csv', sep=',',encoding='GB18030')

shouxin['客户名称']=shouxin['客户名称'].astype(str)


for i in range(0,len(shouxin)):
  if '银行' in shouxin.loc[i,'客户名称']:
        shouxin.loc[i,'d']=4  #挑选出所有银行

  if '含' in  str(shouxin.loc[i,'额度到期日']):
     shouxin.loc[i,'额度到期日']='2010-01-01'  #把shouxin的表中有不规范的到期日格式排除

  shouxin.loc[i,'额度到期日']=str(shouxin.loc[i,'额度到期日']).replace(' 00:00:00','')



for j in range(0,len(shouxin)):
  for i in range(0,len(jia_df)):
    if jia_df.loc[i,'银行类型'] in shouxin.loc[j,'客户名称']:
        shouxin.loc[j,'d']='已有'
        if jia_df.loc[i,'授信有效']==shouxin.loc[j,'客户状态'] and jia_df.loc[i,'我行评级']==shouxin.loc[j,'本年度信用评级'] and jia_df.loc[i,'生效截至日']==shouxin.loc[j,'额度到期日']  :
            continue
        else:


            print(jia_df.loc[i,'银行类型'] )
            print(jia_df.loc[i,'授信有效'] )
            print(shouxin.loc[j,'客户状态'] )
            print(jia_df.loc[i,'我行评级'])
            print(shouxin.loc[j,'本年度信用评级'])


            
            jia_df.loc[i,'更新日期']=riqi
            jia_df.loc[i,'授信有效']=shouxin.loc[j,'客户状态']
            jia_df.loc[i,'我行评级']=shouxin.loc[j,'本年度信用评级']
            jia_df.loc[i,'生效截至日']=shouxin.loc[j,'额度到期日'] 
        break
  


shouxin=shouxin[shouxin['d']!='已有']
shouxin= shouxin.reset_index(drop=True)    #重新定义索引
for i in range(0,len(shouxin)):
    if shouxin.loc[i,'本年度信用评级'] in am and ('银行' in shouxin.loc[i,'客户名称']):
        shouxin.loc[i,'d']=2      #挑选出A-及以上的银行
    
    elif shouxin.loc[i,'本年度信用评级'] in bbb and ('银行' in shouxin.loc[i,'客户名称']):
        shouxin.loc[i,'d']=3      #挑选出BBB+及以上的银行

    elif ('财务' in shouxin.loc[i,'客户名称']):
        shouxin.loc[i,'d']=5      #财务公司        

jia_df=jia_df.set_index('银行类型')    
url3='C:/Users/yangbing/gitskills/转贴现买断价格计算/xin.xls'

writer = pd.ExcelWriter(url3)
shouxin.to_excel(writer,'Sheet1')
writer.save()


url3='C:/Users/yangbing/gitskills/转贴现买断价格计算/jia-评级.xls'
writer = pd.ExcelWriter(url3)
jia_df.to_excel(writer,'Sheet1')
writer.save()
