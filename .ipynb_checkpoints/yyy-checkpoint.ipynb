# %% [markdown]
# # 匹配我行可以收票

# %%
import csv,xlrd,xlwt,datetime,time,re
import numpy as np

import pandas as pd
#一、导入指导价
#二、打开对方清单
def suanqingdan():
    suanqingdan=0
    global url
    shijian0=time.strftime('%Y-%m-%d',time.localtime(time.time()))
    shijian=datetime.datetime.strptime(shijian0 , "%Y-%m-%d")#转为日期格式
    shijian=str(shijian.strftime("%Y-%m-%d"))
   # shijian='2019-04-302'
    
    
    #jin=pd.read_table('jin.csv',sep=',')
    jin=pd.read_excel('jin.xls',encoding='GB18030')
    jin=jin[jin['客户名称']!='作废']
    #jin=jin.set_index('客户名称')

    jia_df=pd.read_excel('D:/20190409部分/20180929桌面备份/报买断业务/转贴现买断价格计算/jia.xls',encoding='GB18030')
  #  print(jin['客户名称'])
  #  stop
    for i in range (0,len(jin)):     
           for j in range (0,len(jia_df)):
               if (jia_df.loc[j,'银行类型'] in jin.loc[i,'客户名称'])  :
                   jin.loc[i,'银行分类']=jia_df.loc[j,'银行分类']
    print(jin)

    jin.to_excel('jin.xls')
suanqingdan()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
#                  客户名称    2019-04-26    2019-04-30    2019-05-05    2019-05-06  \
# 0            一汽财务有限公司  2.900317e+09  2.883941e+09  2.866994e+09  2.856794e+09
# 1          三井住友银行（中国）  2.292222e+08  2.292222e+08  2.292222e+08  2.292222e+08
# 2        三菱东京日联银行（中国）  2.222222e+08  2.222222e+08  2.222222e+08  2.222222e+08
# 3         三门峡银行股份有限公司  1.110000e+00  1.110000e+00  1.110000e+00  1.110000e+00
# 4      上海农村商业银行股份有限公司  5.918429e+08  5.906531e+08  5.907921e+08  5.380421e+08
# 5        上海华瑞银行股份有限公司  5.989400e+06  4.989400e+06  6.989400e+06  6.989400e+06
# 6      上海汽车集团财务有限责任公司  9.839188e+09  9.840188e+09  9.857626e+09  9.857626e+09
# 7      上海浦东发展银行股份有限公司  1.025042e+09  9.486732e+08  1.205754e+09  1.153119e+09
# 8      上海电气集团财务有限责任公司  1.277774e+08  1.258173e+08  1.240802e+08  1.169402e+08
# 9          上海银行股份有限公司  2.422560e+03  6.987107e+07  2.779533e+07  2.083122e+07
# 10         上饶银行股份有限公司  3.576071e+08  3.544048e+08  3.644863e+08  3.640755e+08
# 11           东亚银行（中国）  2.184201e+07  2.214201e+07  2.214201e+07  2.550777e+07
# 12     东莞农村商业银行股份有限公司  1.297863e+09  1.297598e+09  1.296769e+09  1.296147e+09
# 13         东莞银行股份有限公司  4.107731e+06  8.214990e+06  1.964914e+06  6.417771e+06
# 14         东营银行股份有限公司  4.739663e+06  6.239663e+06  5.568663e+06  5.025663e+06
# 15           中交财务有限公司  5.275356e+08  5.439771e+08  5.388831e+08  5.360605e+08
# 16               中信信托  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
# 375          其他授信银行  1.664170e+05  20101008  20190930  1.664170e+05
# 376          其他授信银行  7.134133e+04  20101122  20170904  7.134133e+04
# 377          其他授信银行  3.586465e+06  20131029  20190930  1.888646e+07
# 378          其他授信银行  9.800000e+06  20160321  20190930  9.800000e+06
# 379          其他授信银行  1.000000e-02  20131010  20190930  1.000000e-02
# 380          其他授信银行  4.982703e+08  20190410  20200331  4.942703e+08
# 381             NaN  2.777778e+07  20140218  20151008  2.777778e+07
# 382            二类准入  4.800415e+08  20100915  20190930  4.799623e+08
# 383          其他授信银行  9.390000e+05  20100915  20191130  9.390000e+05
# 384          其他授信银行  4.056465e+06  20100915  20190415  4.056465e+06
# 385          其他授信银行  2.401111e+07  20170103  20180830  2.401111e+07
# 386          其他授信银行  3.333333e+06  20131104  20160120  3.333333e+06
# 387  商票、授信财务公司（国股贴）  1.600000e+08  20190428  20190831  1.235000e+08
# 388  商票、授信财务公司（国股贴）  1.000000e+08  20181109  20190731  1.000000e+08
# 389  商票、授信财务公司（国股贴）  9.260000e+06  20181008  20190930  6.000000e+04
# 390          其他授信银行  1.030277e+08  20170103  20190930  1.023277e+08
# 391          其他授信银行  4.121479e+07  20140218  20190831  1.111479e+07
# 392            二类准入  2.047317e+08  20100915  20190801  2.020476e+08
# 393          其他授信银行  2.799606e+06  20101122  20190930  2.799606e+06
# 394          其他授信银行  3.447200e+04  20100915  20190930  1.903447e+07
# 395             NaN  2.222222e+08  20150206  20150728  2.222222e+08
# 396  商票、授信财务公司（国股贴）  2.668562e+05  20170830  20190630  5.847975e+05
# 397  商票、授信财务公司（国股贴）  1.111111e+08  20170830  20170830  1.111111e+08
# 398             NaN  1.000000e+08  20121116  20121116  1.000000e+08
# 399          其他授信银行  4.555556e+07  20141028  20180630  4.555556e+07
# 400             NaN  1.000000e+08  20140218  20151008  1.000000e+08
# 401          其他授信银行  1.111111e+08  20160310  20160930  1.111111e+08
# 402          其他授信银行  2.106871e+05  20100915  20191031  2.706871e+05
# 403          其他授信银行  1.079048e+06  20100915  20191031  5.509281e+06
# 404          其他授信银行  1.550000e+08  20130320  20180930  1.550000e+08
#
# [405 rows x 10 columns]

# %% [markdown]
# # 1.下载数据

# %%
import csv,xlrd,xlwt,datetime,time,re
import numpy as np

import pandas as pd


#一、导入指导价


#二、打开对方清单
def suanqingdan():
    suanqingdan=0
    global url
    shijian0=time.strftime('%Y-%m-%d',time.localtime(time.time()))
    shijian=datetime.datetime.strptime(shijian0 , "%Y-%m-%d")#转为日期格式
    shijian=str(shijian.strftime("%Y-%m-%d"))
   # shijian='2019-04-302'
    
    
    #jin=pd.read_table('jin.csv',sep=',')
    jin=pd.read_excel('jin.xls',encoding='GB18030')
    jin=jin[jin['客户名称']!='作废']
    jin=jin.set_index('客户名称')



#2.2确认列名，到时候可以删除
    url=input('文件名:')
    if url=='':
        print('dd')
        
        
    else:    
        qing=pd.read_excel(url)
        qing=qing[['客户名称','生效起始日','生效截至日','可用额度']]  #,
        qing=qing[qing['客户名称']!='作废']


        
        qing=qing.set_index('客户名称')
        qing.rename(columns={'可用额度':shijian}, inplace=True)
        del jin['生效起始日']
        del jin['生效截至日']
        print(jin.head())
        
        print(qing.head())
        print(jin.tail())
        
        print(qing.tail())

        jin=jin.join(qing,how='outer')


    jin.to_excel('jin.xls')
suanqingdan()
# Out:
# 文件名:CreditInfo20190509165301.et
#                 Unnamed: 0    2019-04-26    2019-04-30    2019-05-05  \
# 客户名称
# 一汽财务有限公司                 0  2.900317e+09  2.883941e+09  2.866994e+09
# 三井住友银行（中国）               1  2.292222e+08  2.292222e+08  2.292222e+08
# 三菱东京日联银行（中国）             2  2.222222e+08  2.222222e+08  2.222222e+08
# 三门峡银行股份有限公司              3  1.110000e+00  1.110000e+00  1.110000e+00
# 上海农村商业银行股份有限公司           4  5.918429e+08  5.906531e+08  5.907921e+08
#
#                   2019-05-06         银行分类    2019-05-07    2019-05-08
# 客户名称
# 一汽财务有限公司        2.856794e+09  准入财务公司（国股贴）  2.846217e+09  2.810471e+09
# 三井住友银行（中国）      2.292222e+08          NaN  2.292222e+08  2.292222e+08
# 三菱东京日联银行（中国）    2.222222e+08          NaN  2.222222e+08  2.222222e+08
# 三门峡银行股份有限公司     1.110000e+00          NaN  1.110000e+00  1.110000e+00
# 上海农村商业银行股份有限公司  5.380421e+08         一类准入  5.373519e+08  5.351119e+08
#                    生效起始日     生效截至日    2019-05-09
# 客户名称
# 国家开发银行          20100914  20190930  8.637477e+09
# 中国农业发展银行        20100914  20190930  4.469600e+09
# 中国进出口银行         20100914  20190131  2.000000e+10
# 兴化农村商业银行股份有限公司  20121116  20121116  2.000000e+07
# 驻马店银行股份有限公司     20121116  20121116  1.000000e+08
#                   Unnamed: 0    2019-04-26    2019-04-30    2019-05-05  \
# 客户名称
# 黄山太平农村商业银行股份有限公司         400  1.000000e+08  1.000000e+08  1.000000e+08
# 黑河农村商业银行股份有限公司           401  1.111111e+08  1.111111e+08  1.111111e+08
# 齐商银行股份有限公司               402  9.850750e+05  3.255075e+06  4.068714e+04
# 齐鲁银行股份有限公司               403  7.318913e+07  6.748193e+07  5.641478e+06
# 龙江银行股份有限公司               404  1.550000e+08  1.550000e+08  1.550000e+08
#
#                     2019-05-06    银行分类    2019-05-07    2019-05-08
# 客户名称
# 黄山太平农村商业银行股份有限公司  1.000000e+08     NaN  1.000000e+08  1.000000e+08
# 黑河农村商业银行股份有限公司    1.111111e+08  其他授信银行  1.111111e+08  1.111111e+08
# 齐商银行股份有限公司        3.410687e+06  其他授信银行  2.106871e+05  2.706871e+05
# 齐鲁银行股份有限公司        3.062978e+06  其他授信银行  1.079048e+06  5.509281e+06
# 龙江银行股份有限公司        1.550000e+08  其他授信银行  1.550000e+08  1.550000e+08
#                      生效起始日     生效截至日    2019-05-09
# 客户名称
# 铜陵农村商业银行股份有限公司    20150225  20170830  1.000000e-02
# 西班牙对外银行           20160114  20160120  1.666667e+08
# 浙江上虞农村商业银行股份有限公司  20171211  20180630  5.555556e+07
# 上海华瑞银行股份有限公司      20171211  20191130  3.989400e+06
# 浙江南浔农村商业银行股份有限公司  20171211  20190918  1.677473e+06

# %% [markdown]
# # 分析变动

# %%
import pandas as pd
import numpy,math,time,datetime
jin=pd.read_excel('jin.xls',encoding='GB18030')
shijian0=time.strftime('%Y-%m-%d',time.localtime(time.time()))
shijian=datetime.datetime.strptime(shijian0 , "%Y-%m-%d")#转为日期格式
shijian=str(shijian.strftime("%Y-%m-%d"))
jincolumn=jin.columns.values.tolist()  
jincolumn.remove('客户名称')
jincolumn.remove('银行分类')

jincolumn.remove('生效起始日')
jincolumn.remove('生效截至日')
print('已经收集的日期有：')
print(jincolumn)
zuijinri=max(jincolumn)
jincolumn.remove(zuijinri)
shangyiri=max(jincolumn)
print('最近日期：')

print(zuijinri)
print('上一日期：')
print(shangyiri)


jin[shangyiri]=jin[shangyiri].astype('float')/100000000
jin[zuijinri]=jin[zuijinri].astype('float')/100000000
jin['改变']=0
for i in range(0,len(jin)):
    if math.isnan(jin.loc[i,zuijinri]) and  not math.isnan(jin.loc[i,shangyiri]):
             print('删除名单')
             print('%s     %s     %s    %s'%(jin.loc[i,'客户名称'],jin.loc[i,shangyiri],jin.loc[i,'生效起始日'],jin.loc[i,'生效截至日']))
             jin.loc[i,'改变']=1
    elif not math.isnan(jin.loc[i,zuijinri]) and  math.isnan(jin.loc[i,shangyiri]):    
             print('新增名单:')
             print('%s     %s     %s    %s'%(jin.loc[i,'客户名称'],jin.loc[i,zuijinri],jin.loc[i,'生效起始日'],jin.loc[i,'生效截至日']))
             jin.loc[i,'改变']=1
    jin.loc[i,'%s变动'%zuijinri]=(jin.loc[i,zuijinri]-jin.loc[i,shangyiri])


jin=jin[jin['改变']!=1]
jin = jin.sort_values(by=('%s变动'%zuijinri), ascending=False)
print('\n')
print('一、可用余额总共新增：%s 亿元'%(jin['%s变动'%zuijinri].sum()))
jin=jin.round({'%s变动'%zuijinri:2})
jin=jin.round({zuijinri:2})
jin=jin.round({shangyiri:2})



jin0=jin[['客户名称','生效截至日',zuijinri,'%s变动'%zuijinri]]
jin0=jin0.reset_index(drop = True)
print(jin0.head(15))
print('\n')
print(jin0.tail(15))

print('\n')
print('二、各银行分类的可用余额变动：')
jin['生效截至日']=jin['生效截至日'].astype('str')
jin['生效截至日']=pd.to_datetime(jin['生效截至日']) .astype('str')
jin1=jin[jin['生效截至日']>=shijian]
jin1=jin1.reset_index(drop = True)
jin1 = jin1.sort_values(by=('%s'%zuijinri), ascending=True)
jin1=jin1.reset_index(drop = True)


jinfen=jin1['%s变动'%zuijinri].groupby([jin1['银行分类']]).sum()
print(jinfen)
# Out:
# 已经收集的日期有：
# ['2019-04-26', '2019-04-30', '2019-05-05', '2019-05-06', '2019-05-07', '2019-05-08', '2019-05-09']
# 最近日期：
# 2019-05-09
# 上一日期：
# 2019-05-08
#
#
# 一、可用余额总共新增：1.8836308274999887 亿元
#                  客户名称     生效截至日  2019-05-09  2019-05-09变动
# 0        中国民生银行股份有限公司  20190930        5.77          3.73
# 1          招商银行股份有限公司  20190930       13.79          2.54
# 2          江苏银行股份有限公司  20190930        3.60          1.51
# 3          汉口银行股份有限公司  20191031        3.75          1.01
# 4          浙商银行股份有限公司  20190930       10.69          0.46
# 5          平安银行股份有限公司  20190930       35.33          0.40
# 6          天津银行股份有限公司  20191130        0.38          0.38
# 7          华夏银行股份有限公司  20190930        3.98          0.35
# 8        中国建设银行股份有限公司  20190930       26.24          0.34
# 9         平顶山银行股份有限公司  20191130        0.35          0.32
# 10  江苏张家港农村商业银行股份有限公司  20190328        0.98          0.31
# 11         桂林银行股份有限公司  20191130        0.27          0.26
# 12     上海浦东发展银行股份有限公司  20190930       10.92          0.24
# 13         中信银行股份有限公司  20190930       14.02          0.19
# 14         甘肃银行股份有限公司  20190930        0.25          0.19
#
#
#                  客户名称     生效截至日  2019-05-09  2019-05-09变动
# 390      焦作中旅银行股份有限公司  20200229        0.00         -0.20
# 391  合肥科技农村商业银行股份有限公司  20190930        0.01         -0.24
# 392        晋商银行股份有限公司  20190930        0.03         -0.28
# 393        宁波银行股份有限公司  20190930        0.98         -0.30
# 394        中原银行股份有限公司  20191231        5.55         -0.31
# 395        中国银行股份有限公司  20190930       14.98         -0.37
# 396        广发银行股份有限公司  20190930        9.15         -0.38
# 397    北京农村商业银行股份有限公司  20190930       10.12         -0.41
# 398        晋城银行股份有限公司  20190831        0.03         -0.42
# 399        江西银行股份有限公司  20190930        0.05         -0.55
# 400        渤海银行股份有限公司  20190930        2.06         -0.75
# 401      中国光大银行股份有限公司  20190930        5.34         -1.03
# 402      中国农业银行股份有限公司  20190930       22.66         -1.04
# 403        兴业银行股份有限公司  20190930        2.13         -1.12
# 404      中国工商银行股份有限公司  20190930       21.48         -1.24
#
#
# 二、各银行分类的可用余额变动：
# 银行分类
# 一类准入             -1.57
# 二类准入             -0.15
# 其他授信银行           -0.49
# 准入财务公司（国股贴）      -0.24
# 商票、授信财务公司（国股贴）   -0.10
# 国股                2.46
# 大商                1.58
# 资管、证券、金融公司        0.00
# Name: 2019-05-09变动, dtype: float64

# %% [markdown]
# # 查询具体银行变动

# %%
import pandas as pd
import numpy,math,time,datetime
from matplotlib.font_manager import FontProperties  
jin=pd.read_excel('jin.xls',encoding='GB18030')
font_set = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12) #用于在散点图中输出中文

print('请输入要查询的银行')
zhiling=input('    请输入指令“1”来确认执行：')
if zhiling=='':
       print('    终止。')
       stop 

zhilinglist=zhiling.split(",")
jin1=pd.Dataframe({})
for i in range(0,zhilinglist):
    jin=jin[jin['客户名称'].str.contains(zhilinglist[i])]
    del jin['生效起始日']
    del jin['生效截至日']
    del jin['银行分类']
    jin=jin.set_index('客户名称')
    jin0=jin.T
    jin1=pd.concat([jin0,jin1],axis=1)
print(jin0)    
    
    
    
    
    
jincolumn=jin1.columns.values.tolist()  
for i in range(0 ,len(jincolumn)):
    jin1[jincolumn[i]]=jin1[jincolumn[i]]/100000000
jin1=jin1.round(2)
print(jin1)

import matplotlib.pyplot as plt
jin1.plot(kind='line', alpha=1,stacked=True)
plt.legend(prop=font_set)  #显示lable
plt.xlabel('日期',fontproperties=font_set)
plt.ylabel('剩余可用余额',fontproperties=font_set)
#plt.title('理财发行', fontproperties=font_set) 
plt.gcf().autofmt_xdate()  # 自动旋转日期标记
plt.show()
