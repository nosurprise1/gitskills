# %% [markdown]
# # shan（判断票据中介）数据库

# %% [markdown]
# ## 读取

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient

client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
#client = MongoClient('139.196.79.93', 27017)
db2 = client.shan
collection2 = db2.shan   
cursor2 = collection2.find()
shan_df = pd.DataFrame(list(cursor2))
shan_df=shan_df[['xuhao','yinhang','fenlei1','fenlei2','fenlei3','过滤']]
shan_df1=shan_df[shan_df['过滤']>=1]
shan_df1= shan_df1.reset_index(drop=True)    #重新定义索引
shan_df2=shan_df[shan_df['过滤']>=2]
shan_df2= shan_df2.reset_index(drop=True)    #重新定义索引
print(shan_df2)
# Out:
#     xuhao                  yinhang fenlei1  fenlei2  fenlei3  过滤
# 0     117                       工行      工行        1        2   2
# 1     118                       工票      工行        1        2   2
# 2     119                       工商      工行        1        2   2
# 3     120                       建行      建行        1        2   2
# 4     121                     建设银行      建行        1        2   2
# 5     122                       交行      交行        1        2   2
# 6     123                     交通银行      交行        1        2   2
# 7     124                       农行      农行        1        2   2
# 8     125                     农业银行      农行        1        2   2
# 9     126                     中国银行      中行        1        2   2
# 10    127                       中行      中行        1        2   2
# 11    128                       广发      广发        1        3   2
# 12    129                       民生      民生        1        3   2
# 13    130                       平安      平安        1        3   2
# 14    131                       招行      招行        1        3   2
# 15    132                       招商      招行        1        3   2
# 16    133                       光大      光大        1        4   2
# 17    134                       华夏      华夏        1        4   2
# 18    135                       浦发      浦发        1        4   2
# 19    136                       兴业      兴业        1        4   2
# 20    137                       浙商      浙商        1        4   2
# 21    138                       中信      中信        1        4   2
# 22    139                       邮储      邮储        1        2   2
# 23    140                     邮政储蓄      邮储        1        2   2
# 24    141                       联社      农商        1        6   2
# 25    142                       村镇      农商        1        6   2
# 26    143                       农商      农商        1        6   2
# 27    144                       上银      城商        1        5   2
# 28    145                       徽商      城商        1        5   2
# 29    146  [\u4e00-\u9fa5]{2,4}?银行      城商        1        5   2

# %% [markdown]
# ## 从csv文件导入

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
db = client.shan          #得到数据库
collection = db.shan      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='shan.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print(df2)

# %% [markdown]
# ## 删除数据库

# %%
# -*- coding: cp936 -*-
import json,csv,re,time,datetime
import pandas as pd
from pymongo import MongoClient

client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
db = client.shan
collection = db.shan

stop
collection.remove()

# %% [markdown]
# # nickname（微信昵称分类）数据库

# %% [markdown]
# ## 读取

# %%
# -*- coding: cp936 -*-
import json,csv,re,time,datetime
import pandas as pd
from pymongo import MongoClient

client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
# 3347       A.商票-民达利-翁笠℡13669536394   2018-12-1
# 3348         苏中牛志，商票贴现！15205608648   2018-12-1
# 3349        恒大商票丁猛13914035162~上海发奋   2018-12-1
# 3350       A苏中票据 商承 杨传乐15556083476   2018-12-1
# 3351         A亮资摆账 存款高总13608357308   2019-1-31
# 3352        A卓承商银票（钱文泼13732022963）   2019-1-31
# 3353          【恒大商票】丁小宣18738893143   2019-1-31
# 3354         大润金 商票 ￥胡立15639026843   2019-1-31
# 3355                 上海坦格同业。小鲨鱼李大帅   2019-1-31
# 3356         摆账存款～中勤馮先生15801360126   2019-3-29
# 3357       A 商票  肖旭～13667142415～惠利   2019-3-29
#
# [3358 rows x 6 columns]

# %% [markdown]
# ## 从csv文件导入

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
db = client.nickname          #得到数据库
collection = db.nickname      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='nickname.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print(df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print(df2)

# %% [markdown]
# ## 删除数据库

# %%
# -*- coding: cp936 -*-
import json,csv,re,time,datetime
import pandas as pd
from pymongo import MongoClient

client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
db = client.nickname
collection = db.nickname
stop
collection.remove()

# %% [markdown]
# # cun（判断存单业务）数据库

# %% [markdown]
# ## 读取

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient




client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
db = client.cun
collection = db.cun
    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print(df2)
stop
piao_df=df2[['xuhao','ci','shoucun','chucun']]
piao_df=piao_df.set_index('xuhao')
piao_df=piao_df.sort_index(ascending=True)
#print (piao_df.astype(str).ix[1,['ci']].strip().decode('GB18030'))
print(len(piao_df))
print(piao_df)

# %% [markdown]
# ## 从CSV导入

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
#client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
#client = MongoClient('139.196.79.93', 27017)  #建立连接
db = client.cun           #得到数据库
collection = db.cun      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='cun.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print (df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print (df2)

# %% [markdown]
# # fu（判断福费廷）数据库

# %% [markdown]
# ## 读取

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient




client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
#client = MongoClient('139.196.79.93', 27017)
db = client.fu
collection = db.fu
    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
piao_df=df2[['xuhao','ci','shoufu','chufu']]
piao_df=piao_df.set_index('xuhao')
piao_df=piao_df.sort_index(ascending=True)
#print (piao_df.astype(str).ix[1,['ci']].strip().decode('GB18030'))

print(len(piao_df))
# Out:
# ---------------------------------------------------------------------------
# AutoReconnect                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __init__(self, host, port, max_pool_size, document_class, tz_aware, _connect, **kwargs)
#     348             try:
# --> 349                 self.__find_node(seeds)
#     350             except AutoReconnect as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __find_node(self, seeds)
#     749         self.disconnect()
# --> 750         raise AutoReconnect(', '.join(errors))
#     751
#
# AutoReconnect: could not connect to localhost:27017: [WinError 10061] 由于目标计算机积极拒绝，无法连接。
#
# During handling of the above exception, another exception occurred:
#
# ConnectionFailure                         Traceback (most recent call last)
# <ipython-input-1-702df1791ebe> in <module>()
#       8
#       9
# ---> 10 client = MongoClient()
#      11 client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
#      12 #client = MongoClient('139.196.79.93', 27017)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __init__(self, host, port, max_pool_size, document_class, tz_aware, _connect, **kwargs)
#     350             except AutoReconnect as e:
#     351                 # ConnectionFailure makes more sense here than AutoReconnect
# --> 352                 raise ConnectionFailure(str(e))
#     353
#     354         if username:
#
# ConnectionFailure: could not connect to localhost:27017: [WinError 10061] 由于目标计算机积极拒绝，无法连接。

# %% [markdown]
# ## 从csv导入

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
#client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
#client = MongoClient('139.196.79.93', 27017)  #建立连接
db = client.fu           #得到数据库
collection = db.fu      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='fu.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print (df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print (df2)

# %% [markdown]
# # li（判断理财）数据库

# %% [markdown]
# ## 读取

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient




client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
#client = MongoClient('139.196.79.93', 27017)
db = client.li
collection = db.li
    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
piao_df=df2[['xuhao','ci','shouli','chuli']]
piao_df=piao_df.set_index('xuhao')
piao_df=piao_df.sort_index(ascending=True)
#print (piao_df.astype(str).ix[1,['ci']].strip().decode('GB18030'))

print(piao_df)

# %% [markdown]
# ## 从CSV导入

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient

#client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
#client = MongoClient('139.196.79.93', 27017)  #建立连接
db = client.li             #得到数据库
collection = db.li      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='li.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print (df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print (df2)

# %% [markdown]
# # piao（判断票据）数据库

# %% [markdown]
# ## 读取

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient





client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')

db = client.piao
collection = db.piao
    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
piao_df=df2[['xuhao','ci','shou','chu','shoudai','chudai','shouhui','chuhui']]
piao_df=piao_df.set_index('xuhao')
piao_df=piao_df.sort_index(ascending=True)
#print (piao_df.astype(str).ix[1,['ci']].strip())
c=piao_df.astype(str).loc[163,'ci'].strip()
print(c)
print(piao_df)

# %% [markdown]
# ## 从CSV导入

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')

#client = MongoClient()
#client = MongoClient('139.196.79.93', 27017)  #建立连接

#db=client.authenticate("root","5768116",mechanism="SCRAM-SHA-1").piao
db = client.piao           #得到数据库
#db.authenticate("admin", "5768116")
collection = db.piao      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='piao.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print (df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print (df2)


#post = {"author": "Mike33", "text": "My first blog post!","tags": ["mongodb", "python", "pymongo"],"date": datetime.datetime.utcnow()}
#posts = db.posts
#post_id = posts.insert_one(post).inserted_id
#print post_id
#print posts.find_one()
#print posts.find_one({"author": "Mike33"})
#print posts.count()
#print post.find()

# %% [markdown]
# ## 删除

# %%
# -*- coding: cp936 -*-
import json,csv,re,time,datetime
import pandas as pd
from pymongo import MongoClient

client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
db = client.piao
collection = db.piao




collection.remove()

# %% [markdown]
# # piaofen（微信群消息原始数据）数据库

# %% [markdown]
# ## 读取

# %%
# -*- coding: cp936 -*-
import json,re,time,datetime
import csv,xlrd,xlwt

import pandas as pd
from pymongo import MongoClient

client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
db = client.piaofen
collection = db.piaofen

cursor = collection.find({'time':{'$gte':'2019-11-28'}})      #选出中资讯数据库
#cursor = collection.find({"$and":[{'time':{'$gte':'2019-06-03'}}
                                        #            ]})      #选出中资讯数据库
#cursor = collection.find({ "$and":[{'time':'2019-06-19'},{'content':{'$regex':'诚寻有资源朋友合作共'}},{'leixing':189}]})  #删除早于该时间点的数据
#cursor = collection.find({ "$and":[{'time':'2019-07-05'},{'leixing':'189'}]})  #删除早于该时间点的数据

# 1      ...              NaN    0       0       0      0        0       0
# 2      ...              NaN    0       0       0      0        0       0
# 3      ...              NaN    0       0       0      0        0       0
# 4      ...              NaN    0       0       0      0        0       0
# 5      ...              NaN    0       0       0      0        0       0
# 6      ...              NaN    1       0       0      0        0       0
# 7      ...              NaN    0       0       0      0        0       0
# 8      ...              NaN    0       0       0      0        0       0
# 9      ...              NaN    1       0       0      0        0       0
# 10     ...              NaN    0       0       0      0        0       0
# 11     ...              NaN    1       0       0      0        0       0
# 12     ...              NaN    0       0       0      0        0       0
# 13     ...              NaN    0       0       0      0        0       0
# 14     ...              NaN    0       0       0      0        0       0
# 15     ...              NaN    1       0       0      0        0       0
# 16     ...              NaN    0       0       0      0        0       0
# 17     ...              NaN    0       0       0      0        0       0
# 18     ...              NaN    0       0       0      0        0       0
# 19     ...              NaN    0       0       0      0        0       0
# 20     ...              NaN    0       0       0      0        0       0
# 21     ...              NaN    0       0       0      0        0       0
# 22     ...              NaN    0       0       0      0        0       0
# 23     ...              NaN    1       0       0      0        0       0
# 24     ...              NaN    1       0       0      0        0       0
# 25     ...              NaN    1       0       0      0        0       0
# 26     ...              NaN    1       0       0      0        0       0
# 27     ...              NaN    0       0       0      0        0       0
# 28     ...              NaN    1       0       0      0        0       0
# 29     ...              NaN    1       0       0      0        0       0
# ..     ...              ...  ...     ...     ...    ...      ...     ...
# 98     ...              NaN    0       0       0      0        0       0
# 99     ...              NaN    0       0       0      0        0       0
# 100    ...              NaN    0       0       0      0        0       0
# 101    ...              NaN    1       0       0      0        0       0
# 102    ...              NaN    0       0       0      0        0       0
# 103    ...              NaN    1       0       0      0        0       0
# 104    ...              NaN    0       0       0      0        0       0
# 105    ...              NaN    0       0       0      0        0       0
# 106    ...              NaN    0       0       0      0        0       0
# 107    ...              NaN    0       0       0      0        0       0
# 108    ...              NaN    0       0       0      0        0       0
# 109    ...              NaN    0       0       0      0        0       0
# 110    ...              NaN    0       0       0      0        0       0
# 111    ...              NaN    0       0       0      0        0       0
# 112    ...              NaN    0       0       0      0        0       0
# 113    ...              NaN    0       0       0      0        0       0
# 114    ...              NaN    1       0       0      0        0       0
# 115    ...              NaN    0       0       0      0        0       0
# 116    ...              NaN    1       0       0      0        0       0
# 117    ...              NaN    0       0       1      0        0       0
# 118    ...              NaN    0       0       1      0        0       0
# 119    ...        💵同业资金交流群💵    0       0       0      0        0       0
# 120    ...     宇宙无敌票据、水果交流群    1       0       0      0        0       0
# 121    ...              NaN    1       0       0      0        0       0
# 122    ...              NaN    0       0       0      0        0       0
# 123    ...     结盟|股份制银行圈|2群    0       0       0      0        0       0
# 124    ...     全国票据、商票、电票交流    0       0       0      0        0       0
# 125    ...              NaN    0       0       0      0        0       0
# 126    ...              NaN    0       0       0      0        0       0
# 127    ...         同业资金票据交流    0       0       0      0        0       0
#
#            time  time2       uuu
# 0    2019-11-28  09:24       NaN
# 1    2019-11-28  09:24       NaN
# 2    2019-11-28  09:24       NaN
# 3    2019-11-28  09:24       NaN
# 4    2019-11-28  09:25       NaN
# 5    2019-11-28  09:25       NaN
# 6    2019-11-28  09:26       NaN
# 7    2019-11-28  09:26       NaN
# 8    2019-11-28  09:26       NaN
# 9    2019-11-28  09:26       NaN
# 10   2019-11-28  09:27       NaN
# 11   2019-11-28  09:28       NaN
# 12   2019-11-28  09:29       NaN
# 13   2019-11-28  09:29       NaN
# 14   2019-11-28  09:30       NaN
# 15   2019-11-28  09:31       NaN
# 16   2019-11-28  09:32       NaN
# 17   2019-11-28  09:33       NaN
# 18   2019-11-28  09:33       NaN
# 19   2019-11-28  09:33       NaN
# 20   2019-11-28  09:35       NaN
# 21   2019-11-28  09:35       NaN
# 22   2019-11-28  09:36       NaN
# 23   2019-11-28  09:37       NaN
# 24   2019-11-28  09:37       NaN
# 25   2019-11-28  09:38       NaN
# 26   2019-11-28  10:15       NaN
# 27   2019-11-28  10:15       NaN
# 28   2019-11-28  10:16       NaN
# 29   2019-11-28  10:16       NaN
# ..          ...    ...       ...
# 98   2019-11-28  15:43       NaN
# 99   2019-11-28  15:45       NaN
# 100  2019-11-28  15:48       NaN
# 101  2019-11-28  15:51       NaN
# 102  2019-11-28  15:51       NaN
# 103  2019-11-28  15:52       NaN
# 104  2019-11-28  15:54       NaN
# 105  2019-11-28  15:59       NaN
# 106  2019-11-28  16:03       NaN
# 107  2019-11-28  16:06       NaN
# 108  2019-11-28  16:06       NaN
# 109  2019-11-28  16:06       NaN
# 110  2019-11-28  16:10       NaN
# 111  2019-11-28  16:10       NaN
# 112  2019-11-28  16:10       NaN
# 113  2019-11-28  16:10       NaN
# 114  2019-11-28  16:11       NaN
# 115  2019-11-28  16:11       NaN
# 116  2019-11-28  16:12       NaN
# 117  2019-11-28  16:12       NaN
# 118  2019-11-28  16:14       NaN
# 119  2019-11-28  16:15  Thread-8
# 120  2019-11-28  16:15  Thread-9
# 121  2019-11-28  16:15       NaN
# 122  2019-11-28  16:16       NaN
# 123  2019-11-28  16:17  Thread-9
# 124  2019-11-28  16:17  Thread-8
# 125  2019-11-28  16:17       NaN
# 126  2019-11-28  16:18       NaN
# 127  2019-11-28  16:18  Thread-8
#
# [128 rows x 24 columns]

# %% [markdown]
# ## 从CSV导入

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
db = client.piaofen          #得到数据库
collection = db.piaofen      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='record.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print(df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print(df2)


#post = {"author": "Mike33", "text": "My first blog post!","tags": ["mongodb", "python", "pymongo"],"date": datetime.datetime.utcnow()}
#posts = db.posts
#post_id = posts.insert_one(post).inserted_id
#print post_id
#print posts.find_one()
#print posts.find_one({"author": "Mike33"})
#print posts.count()
#print post.find()

# %% [markdown]
# ## 删除数据库

# %%
# -*- coding: cp936 -*-
import json,csv,re,time,datetime
import pandas as pd
from pymongo import MongoClient

client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
db = client.piaofen
collection = db.piaofen





collection.remove({ "$and":[{'time':'2020-11-02'},{'nickname':'陈良兴'}]})  #删除早于该时间点的数据

#collection.remove({'time':{'$lte':'2019-04-20'}})  #删除早于该时间点的数据
# Out:
# ---------------------------------------------------------------------------
# AutoReconnect                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __init__(self, host, port, max_pool_size, document_class, tz_aware, _connect, **kwargs)
#     348             try:
# --> 349                 self.__find_node(seeds)
#     350             except AutoReconnect as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __find_node(self, seeds)
#     749         self.disconnect()
# --> 750         raise AutoReconnect(', '.join(errors))
#     751
#
# AutoReconnect: could not connect to 121.196.220.14:27017: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectionFailure                         Traceback (most recent call last)
# <ipython-input-1-8dca8a5455cd> in <module>()
#       4 from pymongo import MongoClient
#       5
# ----> 6 client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
#       7 db = client.piaofen
#       8 collection = db.piaofen
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __init__(self, host, port, max_pool_size, document_class, tz_aware, _connect, **kwargs)
#     350             except AutoReconnect as e:
#     351                 # ConnectionFailure makes more sense here than AutoReconnect
# --> 352                 raise ConnectionFailure(str(e))
#     353
#     354         if username:
#
# ConnectionFailure: could not connect to 121.196.220.14:27017: timed out

# %% [markdown]
# # piaofenxi（微信群消息分析）数据库

# %% [markdown]
# ## 从piaofen数据库提取piaofenxi

# %%
# -*- coding: cp936 -*-
# -*- coding: utf-8 -*-
import pandas as pd
import time,datetime
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame
import os
import csv,json
from pymongo import MongoClient
from matplotlib.font_manager import FontProperties  
font_set = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=12) #用于在散点图中输出中文
font_set2 = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=9) #用于在散点图中输出中文

#client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')


db5 = client.piaofen
collection5 = db5.piaofen

db6 = client.piaofenxi
collection6 = db6.piaofenxi


#选时间
shijian=time.strftime('%H:%M',time.localtime(time.time()))
shijian2=time.strftime('%Y-%m-%d',time.localtime(time.time()))

shijian2 = datetime.datetime.strptime(shijian2, "%Y-%m-%d")

shijian3=shijian2-datetime.timedelta(days=1)
shijian4=shijian2-datetime.timedelta(days=2)
shijian5=shijian2-datetime.timedelta(days=30)

shijian2=str(shijian2.strftime("%Y-%m-%d"))

shijian3=str(shijian3.strftime("%Y-%m-%d"))
shijian4=str(shijian4.strftime("%Y-%m-%d"))
shijian5=str(shijian5.strftime("%Y-%m-%d"))

shijian=str(shijian)
print(shijian)


cursor = collection5.find()
present_time = pd.DataFrame(list(cursor))



#制作两个表格              
huatudata3=present_time[['time','hanglei1','hanglei2','shou','chu','shoudai','chudai']]
huatudata4=huatudata3.groupby(['time','hanglei1']).sum()

print(huatudata4)


huatudata4.to_csv('cd.csv')

# %% [markdown]
# ## 读取

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
db = client.piaofenxi         #得到数据库
collection = db.piaofenxi      #得到数据集合



cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print(df2)

df2.to_csv('4.csv',encoding='GB18030',mode='w',header=True)
# Out:
#                            _id   出代持     出票  收代持     收票     时间  \
# 0     5c432f86cbbc88394cb8f638   1.0   99.0  1.0   86.0     日终
# 1     5c432f86cbbc88394cb8f639   0.0    0.0  0.0    0.0     日终
# 2     5c432f86cbbc88394cb8f63a   0.0    0.0  0.0    1.0     日终
# 3     5c432f86cbbc88394cb8f63b   0.0    1.0  0.0    0.0     日终
# 4     5c432f86cbbc88394cb8f63c   0.0   11.0  3.0   15.0     日终
# 5     5c432f86cbbc88394cb8f63d   0.0    0.0  0.0    0.0     日终
# 6     5c432f86cbbc88394cb8f63e   0.0    6.0  0.0    5.0     日终
# 7     5c432f86cbbc88394cb8f63f   1.0   12.0  3.0    7.0     日终
# 8     5c432f86cbbc88394cb8f640   0.0    1.0  0.0    0.0     日终
# 9     5c432f86cbbc88394cb8f641   0.0    1.0  0.0    8.0     日终
# 10    5c432f86cbbc88394cb8f642   0.0    2.0  0.0   14.0     日终
# 11    5c432f86cbbc88394cb8f643   0.0    1.0  0.0    1.0     日终
# 12    5c432f86cbbc88394cb8f644   5.0    3.0  0.0    1.0     日终
# 13    5c432f86cbbc88394cb8f645   0.0    2.0  1.0    3.0     日终
# 14    5c432f86cbbc88394cb8f646   0.0    2.0  0.0    1.0     日终
# 15    5c432f86cbbc88394cb8f647   0.0    2.0  0.0    0.0     日终
# 16    5c432f86cbbc88394cb8f648   0.0    2.0  0.0   21.0     日终
# 17    5c432f86cbbc88394cb8f649   2.0   51.0  0.0   74.0     日终
# 18    5c432f86cbbc88394cb8f64a   0.0    1.0  0.0    0.0     日终
# 19    5c432f86cbbc88394cb8f64b   0.0    0.0  0.0    1.0     日终
# 20    5c432f86cbbc88394cb8f64c   0.0    1.0  0.0    3.0     日终
# 21    5c432f86cbbc88394cb8f64d   0.0   11.0  2.0   16.0     日终
# 22    5c432f86cbbc88394cb8f64e   0.0    1.0  0.0    0.0     日终
# 23    5c432f86cbbc88394cb8f64f   0.0    0.0  0.0    1.0     日终
# 24    5c432f86cbbc88394cb8f650   1.0    2.0  1.0    2.0     日终
# 25    5c432f86cbbc88394cb8f651   2.0    8.0  0.0    5.0     日终
# 26    5c432f86cbbc88394cb8f652   0.0    1.0  0.0    0.0     日终
# 27    5c432f86cbbc88394cb8f653   0.0    1.0  3.0    5.0     日终
# 28    5c432f86cbbc88394cb8f654   0.0    0.0  0.0   10.0     日终
# 29    5c432f86cbbc88394cb8f655   0.0    1.0  0.0    0.0     日终
# ...                        ...   ...    ...  ...    ...    ...
# 7881  5d8dd193014f8b02a06b685f   0.0    5.0  0.0    0.0  17:08
# 7882  5d8dd193014f8b02a06b6860   0.0    2.0  0.0    1.0  17:08
# 21               None  农商  2017-10-24
# 22               None  农行  2017-10-24
# 23               None  华夏  2017-10-24
# 24               None  大商  2017-10-24
# 25               None  小商  2017-10-24
# 26               None  工行  2017-10-24
# 27               None  平安  2017-10-24
# 28               None  广发  2017-10-24
# 29               None  建行  2017-10-24
# ...               ...  ..         ...
# 7881  2019-09-27   浦发  浦发  2019-09-27
# 7882  2019-09-27   邮储  邮储  2019-09-27
# 7883  2019-09-29   中介  中介  2019-09-29
# 7884  2019-09-29   中行  中行  2019-09-29
# 7885  2019-09-29   光大  光大  2019-09-29
# 7886  2019-09-29   兴业  兴业  2019-09-29
# 7887  2019-09-29   农商  农商  2019-09-29
# 7888  2019-09-29   华夏  华夏  2019-09-29
# 7889  2019-09-29   城商  城商  2019-09-29
# 7890  2019-09-29   工行  工行  2019-09-29
# 7891  2019-09-29   平安  平安  2019-09-29
# 7892  2019-09-29   广发  广发  2019-09-29
# 7893  2019-09-29   建行  建行  2019-09-29
# 7894  2019-09-29   招行  招行  2019-09-29
# 7895  2019-09-29   民生  民生  2019-09-29
# 7896  2019-09-29   浙商  浙商  2019-09-29
# 7897  2019-09-29   浦发  浦发  2019-09-29
# 7898  2019-09-29   邮储  邮储  2019-09-29
# 7899  2019-09-30   中介  中介  2019-09-30
# 7900  2019-09-30   兴业  兴业  2019-09-30
# 7901  2019-09-30   农商  农商  2019-09-30
# 7902  2019-09-30   华夏  华夏  2019-09-30
# 7903  2019-09-30   城商  城商  2019-09-30
# 7904  2019-09-30   工行  工行  2019-09-30
# 7905  2019-09-30   平安  平安  2019-09-30
# 7906  2019-09-30   广发  广发  2019-09-30
# 7907  2019-09-30   招行  招行  2019-09-30
# 7908  2019-09-30   民生  民生  2019-09-30
# 7909  2019-09-30   浙商  浙商  2019-09-30
# 7910  2019-09-30   浦发  浦发  2019-09-30
#
# [7911 rows x 9 columns]

# %% [markdown]
# ## 从CSV导入

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
db = client.piaofenxi         #得到数据库
collection = db.piaofenxi      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='1.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print(df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print(df2)

# %% [markdown]
# ## 删除数据库

# %%
# -*- coding: cp936 -*-
import json,csv,re,time,datetime
import pandas as pd
from pymongo import MongoClient

client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
db = client.piaofenxi
collection = db.piaofenxi


collection.remove({'统计日期':{'$lte':'2018-04-25'}})  #删除早于该时间点的数据
collection.remove()  #删除早于该时间点的数据
#collection.remove({'统计日期':{'$gte':'2018-09-17'}})  #删除早于该时间点的数据
#collection.remove({'统计日期':''})  #删除早于该时间点的数据
