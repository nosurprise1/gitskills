# %% [markdown]
# # 1.价格更新

# %%
import csv,xlrd,xlwt,datetime,time
import pandas as pd





#一、导入指导价
jia_df=pd.read_excel('转贴现买断价格计算/jia.xls',encoding='GB18030')
jiage=pd.read_excel('转贴现买断价格计算/价格更新/jiage.xls',encoding='GB18030')


jiagecolumn=jiage.columns.values.tolist()[1:]  
jia_dfcolumn=jia_df.columns.values.tolist()[2:7]  

print(jiagecolumn)
print(jia_dfcolumn)

jia_df.columns=['银行类型','银行分类']+jiagecolumn+['授信有效','可用额度','生效截至日','我行评级','更新日期','特殊报价']



#for i in range(0,len(jiagecolumn)):
#     print(i)
#     print(jia_dfcolumn[i])
#     print(jiagecolumn[i])
        
        
#     jia_df.rename(columns={jia_dfcolumn[i]:jiagecolumn[i]}, inplace=True)
#     print(jia_df.head())

print(jia_df)
for i in range(0,len(jia_df)):
  for j in range(0,len(jiage)):
    
    if (jiage.loc[j,'银行分类'] ==jia_df.loc[i,'银行类型']):
       jia_df.loc[i,jia_df.columns[2]]=jiage.loc[j,jiage.columns[1]]
       jia_df.loc[i,jia_df.columns[3]]=jiage.loc[j,jiage.columns[2]]
       jia_df.loc[i,jia_df.columns[4]]=jiage.loc[j,jiage.columns[3]]
       jia_df.loc[i,jia_df.columns[5]]=jiage.loc[j,jiage.columns[4]]
       jia_df.loc[i,jia_df.columns[6]]=jiage.loc[j,jiage.columns[5]]
       jia_df.loc[i,'特殊报价']= '1'
       
       break
    else:
      if  (jia_df.loc[i,'银行分类']==jiage.loc[j,'银行分类']):
               jia_df.loc[i,jia_df.columns[2]]=jiage.loc[j,jiage.columns[1]]
               jia_df.loc[i,jia_df.columns[3]]=jiage.loc[j,jiage.columns[2]]
               jia_df.loc[i,jia_df.columns[4]]=jiage.loc[j,jiage.columns[3]]
               jia_df.loc[i,jia_df.columns[5]]=jiage.loc[j,jiage.columns[4]]
               jia_df.loc[i,jia_df.columns[6]]=jiage.loc[j,jiage.columns[5]]
              # print(str(jia_df.loc[i,'我行评级']))
               break
      else:
               jia_df.loc[i,jia_df.columns[2]]=0
               jia_df.loc[i,jia_df.columns[3]]=0
               jia_df.loc[i,jia_df.columns[4]]=0
               jia_df.loc[i,jia_df.columns[5]]=0
               jia_df.loc[i,jia_df.columns[6]]=0
              # print(str(jia_df.loc[i,'我行评级']))
            #   break

jia_df=jia_df.set_index('银行类型')       
url3='转贴现买断价格计算/jia-价格.xls'
writer = pd.ExcelWriter(url3)
jia_df.to_excel(writer,'Sheet1')
writer.save()
# Out:
# ['2019-09-01至2019-09-30', '2019-11-01至2019-12-30', '2020-02-01至2020-03-30', '2020-04-01至2020-06-30', '2020-07-01至2020-12-30']
# ['2019-09-01至2019-09-30', '2019-11-01至2019-12-30', '2020-02-01至2020-03-30', '2020-04-01至2020-06-30', '2020-07-01至2020-12-30']
#              银行类型              银行分类  2019-09-01至2019-09-30  \
# 0          浦东发展银行         国股（授信银行贴）                   2.80
# 1              浦发         国股（授信银行贴）                   2.80
# 2            兴业银行         国股（授信银行贴）                   2.80
# 3            华夏银行         国股（授信银行贴）                   2.80
# 4            工商银行         国股（授信银行贴）                   2.80
# 5            农业银行         国股（授信银行贴）                   2.80
# 6          农业发展银行         国股（授信银行贴）                   2.80
# 7            中国银行         国股（授信银行贴）                   2.80
# 8            建设银行         国股（授信银行贴）                   2.80
# 9            交通银行         国股（授信银行贴）                   2.80
# 10           光大银行         国股（授信银行贴）                   2.80
# 11           招商银行         国股（授信银行贴）                   2.80
# 12           民生银行         国股（授信银行贴）                   2.80
# 13           中信银行         国股（授信银行贴）                   2.80
# 14           平安银行         国股（授信银行贴）                   2.80
# 15         邮政储蓄银行         国股（授信银行贴）                   2.80
# 16           邮储银行         国股（授信银行贴）                   2.80
# 17           广发银行         国股（授信银行贴）                   2.80
# 18         广东发展银行         国股（授信银行贴）                   2.80
# 19         国家开发银行         国股（授信银行贴）                   2.80
# 20          进出口银行         国股（授信银行贴）                   2.80
# 21           浙商银行         大商（授信银行贴）                   2.85
# 22           北京银行         大商（授信银行贴）                   2.85
# 23           上海银行         大商（授信银行贴）                   2.85
# 24           江苏银行         大商（授信银行贴）                   2.85
# 25           南京银行         大商（授信银行贴）                   2.85
# 26           宁波银行         大商（授信银行贴）                   2.85
# 27           渤海银行              一类准入                   2.90
# 28           徽商银行              一类准入                   2.90
# 29           杭州银行              一类准入                   2.90
# ..            ...               ...                    ...
# 530      工银金融资产投资        资管、证券、金融公司                   0.00
# 531      中国大地财产保险        资管、证券、金融公司                   0.00
# 532    阳光农业相互保险公司        资管、证券、金融公司                   0.00
# 533      中银金融资产投资        资管、证券、金融公司                   0.00
# 534         前海再保险        资管、证券、金融公司                   0.00
# 535      贵阳贵银金融租赁        资管、证券、金融公司                   0.00
# 536           富阳农            其他授信银行                   3.10
# 537           永嘉农            其他授信银行                   3.10
# 538        四川新网银行            其他授信银行                   3.10
# 539        长安汽车金融        资管、证券、金融公司                   0.00
# 540      山东招金集团财务    商票、授信财务公司（国股贴）                   3.20
# 541      中国航油集团财务    商票、授信财务公司（国股贴）                   3.20
# 542      航天科工金融租赁        资管、证券、金融公司                   0.00
# 543      上海尚诚消费金融        资管、证券、金融公司                   0.00
# 544    天津长城滨银汽车金融        资管、证券、金融公司                   0.00
# 545          中煤财务    商票、授信财务公司（国股贴）                   3.20
# 546          烟台银行            其他授信银行                   3.10
# 547        江苏苏宁银行            其他授信银行                   3.10
# 548        南方电网财务    商票、授信财务公司（国股贴）                   3.20
# 549      长沙农村商业银行            其他授信银行                   3.10
# 550      淮南矿业集团财务    商票、授信财务公司（国股贴）                   3.20
# 551      山东豪沃汽车金融        资管、证券、金融公司                   0.00
# 552  四川省宜宾五粮液集团财务    商票、授信财务公司（国股贴）                   3.20
# 553      阳泉煤业集团财务    商票、授信财务公司（国股贴）                   3.20
# 554            其他        国股（非授信银行贴）                   2.83
# 555            其他        大商（非授信银行贴）                   2.90
# 556            其他   商票、授信财务公司（大城商贴）                   3.23
# 557            其他  商票、授信财务公司（一类准入贴）                   3.30
# 558            其他       准入财务公司（国股贴）                   3.45
# 559            其他   准入财务公司（准入财务公司贴）                   3.65
#
#      2019-11-01至2019-12-30  2020-02-01至2020-03-30  2020-04-01至2020-06-30  \
# 0                     2.80                   3.02                   3.15
# 1                     2.80                   3.02                   3.15
# 2                     2.80                   3.02                   3.15
# 3                     2.80                   3.02                   3.15
# 4                     2.80                   3.02                   3.15
# 5                     2.80                   3.02                   3.15
# 6                     2.80                   3.02                   3.15
# 7                     2.80                   3.02                   3.15
# 8                     2.80                   3.02                   3.15
# 9                     2.80                   3.02                   3.15
# 10                    2.80                   3.02                   3.15
# 11                    2.80                   3.02                   3.15
# 12                    2.80                   3.02                   3.15
# 13                    2.80                   3.02                   3.15
# 14                    2.80                   3.02                   3.15
# 15                    2.80                   3.02                   3.15
# 16                    2.80                   3.02                   3.15
# 17                    2.80                   3.02                   3.15
# 18                    2.80                   3.02                   3.15
# 19                    2.80                   3.02                   3.15
# 20                    2.80                   3.02                   3.15
# 21                    2.85                   3.05                   3.18
# 22                    2.85                   3.05                   3.18
# 23                    2.85                   3.05                   3.18
# 24                    2.85                   3.05                   3.18
# 25                    2.85                   3.05                   3.18
# 26                    2.85                   3.05                   3.18
# 27                    2.90                   3.10                   3.23
# 28                    2.90                   3.10                   3.23
# 29                    2.90                   3.10                   3.23
# ..                     ...                    ...                    ...
# 530                   0.00                   0.00                   0.00
# 531                   0.00                   0.00                   0.00
# 532                   0.00                   0.00                   0.00
# 533                   0.00                   0.00                   0.00
# 534                   0.00                   0.00                   0.00
# 535                   0.00                   0.00                   0.00
# 536                   3.10                   3.32                   3.45
# 537                   3.10                   3.32                   3.45
# 538                   3.10                   3.32                   3.45
# 539                   0.00                   0.00                   0.00
# 540                   3.20                   3.45                   3.55
# 541                   3.20                   3.45                   3.55
# 542                   0.00                   0.00                   0.00
# 543                   0.00                   0.00                   0.00
# 544                   0.00                   0.00                   0.00
# 545                   3.20                   3.45                   3.55
# 546                   3.10                   3.32                   3.45
# 547                   3.10                   3.32                   3.45
# 548                   3.20                   3.45                   3.55
# 549                   3.10                   3.32                   3.45
# 550                   3.20                   3.45                   3.55
# 551                   0.00                   0.00                   0.00
# 552                   3.20                   3.45                   3.55
# 553                   3.20                   3.45                   3.55
# 554                   2.83                   3.05                   3.18
# 555                   2.90                   3.10                   3.23
# 556                   3.23                   3.48                   3.58
# 557                   3.30                   3.53                   3.63
# 558                   3.45                   3.45                   3.55
# 559                   3.65                   3.65                   3.65
#
#      2020-07-01至2020-12-30 授信有效          可用额度      生效截至日  我行评级        更新日期  \
# 0                     3.20   有效  1.380453e+04 2019-09-17   AAA         NaN
# 1                     3.20   有效  1.380453e+04 2019-09-17   AAA         NaN
# 2                     3.20   有效  7.703118e+08 2019-09-02  AAA+         NaN
# 3                     3.20   有效  1.684744e+06 2019-09-02   AA-         NaN
# 4                     3.20   有效  9.659693e+09 2019-09-10  AAA+         NaN
# 5                     3.20   有效  9.659693e+09 2019-07-26  AAA+         NaN
# 6                     3.20   有效  1.624090e+10 2019-09-24   AAA         NaN
# 7                     3.20   有效  2.686689e+09 2019-09-04  AAA+  2019-05-27
# 8                     3.20   有效  8.277712e+09 2019-09-10  AAA+         NaN
# 9                     3.20   有效  2.002856e+06 2019-08-12  AAA+         NaN
# 10                    3.20   有效  7.590464e+08 2019-08-12  AAA-         NaN
# 11                    3.20   有效  2.792610e+10 2019-08-07  AAA+         NaN
# 12                    3.20   有效  0.000000e+00 2019-09-10  AAA-         NaN
# 13                    3.20   有效  2.678253e+09 2019-09-10  AAA-         NaN
# 14                    3.20   有效  4.774596e+07 2019-07-26    AA         NaN
# 15                    3.20   有效  1.000000e+10 2019-09-30   NaN         NaN
# 16                    3.20   有效  1.000000e+10 2019-09-30   NaN         NaN
# 17                    3.20   有效  4.798815e+09 2019-08-12    A-         NaN
# 18                    3.20   有效  4.798815e+09 2019-08-12    A-         NaN
# 19                    3.20   有效  8.725544e+09 2019-09-02   AAA         NaN
# 20                    3.20   有效  2.000000e+10 2019-10-22   AAA         NaN
# 21                    3.23   有效  5.050326e+07 2019-07-30    A+         NaN
# 22                    3.23   有效  5.169793e+09 2019-11-12    AA         NaN
# 23                    3.23   有效  2.835730e+09 2019-10-18    AA         NaN
# 24                    3.23   有效  7.262350e+04 2019-08-12   AA-         NaN
# 25                    3.23   有效  9.659778e+08 2019-09-20   AA-         NaN
# 26                    3.23   有效  1.854153e+05 2019-08-27    AA         NaN
# 27                    3.28   有效  7.344446e+05 2019-08-12     A         NaN
# 28                    3.28   有效  4.403999e+09 2019-06-27   AA-         NaN
# 29                    3.28   有效  3.275650e+07 2019-09-18   AA-         NaN
# ..                     ...  ...           ...        ...   ...         ...
# 530                   0.00   有效           NaN 2019-07-01    A-         NaN
# 531                   0.00   有效           NaN 2019-08-07     A         NaN
# 532                   0.00   有效           NaN 2019-09-11   BBB         NaN
# 533                   0.00   有效           NaN 2019-06-04    A-         NaN
# 534                   0.00   有效           NaN 2019-12-02  BBB+         NaN
# 535                   0.00   有效           NaN 2019-08-28   BBB         NaN
# 536                   3.50   有效           NaN 2019-12-23   BBB         NaN
# 537                   3.50   有效           NaN 2019-12-26    A-         NaN
# 538                   3.50   有效           NaN 2019-12-26   BBB         NaN
# 539                   0.00   有效           NaN 2019-09-11     A         NaN
# 540                   3.55   有效           NaN 2019-09-16    A-         NaN
# 541                   3.55   有效           NaN 2020-01-07     A         NaN
# 542                   0.00   失效           NaN 2019-04-28   BBB    20190513
# 543                   0.00   有效           NaN 2019-10-18   BBB         NaN
# 544                   0.00   有效           NaN 2019-06-18    A+         NaN
# 545                   3.55   有效           NaN 2020-03-10    A+         NaN
# 546                   3.50   有效           NaN 2020-03-07  BBB+         NaN
# 547                   3.50   有效           NaN 2020-02-17  BBB-         NaN
# 548                   3.55   有效           NaN 2019-09-30   AA-         NaN
# 549                   3.50   有效           NaN 2020-03-25    A-         NaN
# 550                   3.55   有效           NaN 2019-06-30     A         NaN
# 551                   0.00   有效           NaN 2019-08-15    A+         NaN
# 552                   3.55   有效           NaN 2019-07-22    A+         NaN
# 553                   3.55   有效           NaN 2019-08-30  BBB+         NaN
# 554                   3.23  NaN           NaN        NaT   NaN         NaN
# 555                   3.28  NaN           NaN        NaT   NaN         NaN
# 556                   3.58  NaN           NaN        NaT   NaN         NaN
# 557                   3.63  NaN           NaN        NaT   NaN         NaN
# 558                   3.55  NaN           NaN        NaT   NaN         NaN
# 559                   3.65  NaN           NaN        NaT   NaN         NaN
#
#      特殊报价
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# ..    ...
# 530   NaN
# 531   NaN
# 532   NaN
# 533   NaN
# 534   NaN
# 535   NaN
# 536   NaN
# 537   NaN
# 538   NaN
# 539   NaN
# 540   NaN
# 541   NaN
# 542   NaN
# 543   NaN
# 544   NaN
# 545   NaN
# 546   NaN
# 547   NaN
# 548   NaN
# 549   NaN
# 550   NaN
# 551   NaN
# 552   NaN
# 553   NaN
# 554   NaN
# 555   NaN
# 556   NaN
# 557   NaN
# 558   NaN
# 559   NaN
#
# [560 rows x 13 columns]

# %% [markdown]
# # 信贷评级更新

# %%
import csv,xlrd,xlwt,datetime,time
import pandas as pd





riqi=input('请输入要最新授信表的日期:')
url=input('请输入要最新授信表的文件名（包括后缀）:')

shouxin=pd.read_excel('C:/Users/yangbing/gitskills/转贴现买断价格计算/评级更新/%s'%url,sheetname=1,encoding='GB18030')


shouxin=shouxin[['客户名称','客户状态','额度到期日','本年度信用评级']]

shouxin['d']=0
am=['A-','A','A+','AA-','AA','AA+','AAA-','AAA','AAA+']
bbb=['BBB+']

shouxin= shouxin.reset_index(drop=True)    #重新定义索引


#一、导入指导价
jia_df=pd.read_excel('C:/Users/yangbing/gitskills/转贴现买断价格计算/jia.xls',encoding='GB18030')
#jia_df=pd.read_table('jia2.csv', sep=',',encoding='GB18030')

shouxin['客户名称']=shouxin['客户名称'].astype(str)


for i in range(0,len(shouxin)):
  if '银行' in shouxin.loc[i,'客户名称']:
        shouxin.loc[i,'d']=4  #挑选出所有银行

  if '含' in  str(shouxin.loc[i,'额度到期日']):
     shouxin.loc[i,'额度到期日']='2010-01-01'  #把shouxin的表中有不规范的到期日格式排除

  shouxin.loc[i,'额度到期日']=str(shouxin.loc[i,'额度到期日']).replace(' 00:00:00','')



for j in range(0,len(shouxin)):
  for i in range(0,len(jia_df)):
    if jia_df.loc[i,'银行类型'] in shouxin.loc[j,'客户名称']:
        shouxin.loc[j,'d']='已有'
        if jia_df.loc[i,'授信有效']==shouxin.loc[j,'客户状态'] and jia_df.loc[i,'我行评级']==shouxin.loc[j,'本年度信用评级'] and jia_df.loc[i,'生效截至日']==shouxin.loc[j,'额度到期日']  :
            continue
        else:


            print(jia_df.loc[i,'银行类型'] )
            print(jia_df.loc[i,'授信有效'] )
            print(shouxin.loc[j,'客户状态'] )
            print(jia_df.loc[i,'我行评级'])
            print(shouxin.loc[j,'本年度信用评级'])


            
            jia_df.loc[i,'更新日期']=riqi
            jia_df.loc[i,'授信有效']=shouxin.loc[j,'客户状态']
            jia_df.loc[i,'我行评级']=shouxin.loc[j,'本年度信用评级']
            jia_df.loc[i,'生效截至日']=shouxin.loc[j,'额度到期日'] 
        break
  


shouxin=shouxin[shouxin['d']!='已有']
shouxin= shouxin.reset_index(drop=True)    #重新定义索引
for i in range(0,len(shouxin)):
    if shouxin.loc[i,'本年度信用评级'] in am and ('银行' in shouxin.loc[i,'客户名称']):
        shouxin.loc[i,'d']=2      #挑选出A-及以上的银行
    
    elif shouxin.loc[i,'本年度信用评级'] in bbb and ('银行' in shouxin.loc[i,'客户名称']):
        shouxin.loc[i,'d']=3      #挑选出BBB+及以上的银行

    elif ('财务' in shouxin.loc[i,'客户名称']):
        shouxin.loc[i,'d']=5      #财务公司        

jia_df=jia_df.set_index('银行类型')    
url3='C:/Users/yangbing/gitskills/转贴现买断价格计算/xin.xls'

writer = pd.ExcelWriter(url3)
shouxin.to_excel(writer,'Sheet1')
writer.save()


url3='C:/Users/yangbing/gitskills/转贴现买断价格计算/jia-评级.xls'
writer = pd.ExcelWriter(url3)
jia_df.to_excel(writer,'Sheet1')
writer.save()
