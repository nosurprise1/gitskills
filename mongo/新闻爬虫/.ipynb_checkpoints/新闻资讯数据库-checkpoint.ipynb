# %% [markdown]
# # zixun数据库

# %% [markdown]
# ## 读取zixun数据库

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient
import matplotlib.pyplot as plt  
#from wordcloud import WordCloud  
#import jieba
#import jieba.analyse
  


client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')

db = client.zixun
collection = db.zixun

#cursor = collection.find({'标题':{'$regex':'ABS'}}) 

#cursor = collection.find({'爬取日期':{'$gte':'2018-05-01'}})
#cursor = collection.find({'网站':'交易云'}) 
#cursor = collection.find({'爬取日期':None})
cursor = collection.find()

zixun_df= pd.DataFrame(list(cursor))

print(zixun_df)
# Out:
#                            _id                        位置  \
# 0     5ccebee312e34411b80ee64a                       NaN
# 1     5ccebef512e34411b80ee64e                       NaN
# 2     5ccebf1712e34411b80ee655                       NaN
# 3     5ccebf1c12e34411b80ee656                       NaN
# 4     5ccebf2012e34411b80ee657                       NaN
# 5     5ccebf2e12e34411b80ee65a                       NaN
# 6     5ccebf4012e34411b80ee65e                       NaN
# 7     5ccece57e7a9b846bfd5523c          和讯网>银行>银行行业动态>正文
# 8     5cd56b41e7a9b846bfd553d1            和讯网>新闻>宏观经济>正文
# 9     5cd56b44e7a9b846bfd553d2            和讯网>新闻>宏观经济>正文
# 10    5c432f87cbbc88394cb90a5a                      None
# 11    5ccebef112e34411b80ee64d                       NaN
# 12    5ccebf0912e34411b80ee652                       NaN
# 13    5ccebf4512e34411b80ee65f                       NaN
# 14    5ccece57e7a9b846bfd5523d          和讯网>银行>中资银行资讯>正文
# 15    5cd2e238e7a9b846bfd55320  和讯网>和讯P2P-网贷第一门户>网贷资讯>正文
# 16    5cd2e23be7a9b846bfd55321          和讯网>银行>中资银行资讯>正文
# 17    5cd2e241e7a9b846bfd55324            和讯网>新闻>宏观经济>正文
# 18    5cd2e242e7a9b846bfd55325            和讯网>新闻>宏观经济>正文
# 19    5cd2e243e7a9b846bfd55326            和讯网>新闻>宏观经济>正文
# 20    5cd31a9ce7a9b846bfd55327            和讯网>新闻>宏观经济>正文
# 21    5cd31a9fe7a9b846bfd55328            和讯网>新闻>宏观经济>正文
# 22    5cd36f20e7a9b846bfd55329  和讯网>和讯P2P-网贷第一门户>网贷资讯>正文
# 23    5cd36f20e7a9b846bfd5532a  和讯网>和讯P2P-网贷第一门户>网贷资讯>正文
# 24    5cd36f23e7a9b846bfd5532b            和讯网>新闻>宏观经济>正文
# 25    5cd36f25e7a9b846bfd5532c            和讯网>新闻>宏观经济>正文
# 26    5cd36f26e7a9b846bfd5532d            和讯网>新闻>宏观经济>正文
# 27    5cd36f27e7a9b846bfd5532e            和讯网>新闻>宏观经济>正文
# 28    5cd36f28e7a9b846bfd5532f            和讯网>新闻>宏观经济>正文
# 29    5cd36f2ae7a9b846bfd55330            和讯网>新闻>宏观经济>正文
# ...                        ...                       ...
# 999   5cd8b8c8e7a9b846bfd553ff            和讯网>新闻>宏观经济>正文
# 1000  5cd8b8c8e7a9b846bfd55400            和讯网>新闻>宏观经济>正文
# 1001  5cd8b8d8e7a9b846bfd55401            和讯网>新闻>宏观经济>正文
# 1011     http://iof.hexun.com/2019-05-13/197162854.html
# 1012    http://news.hexun.com/2019-05-13/197163709.html
# 1013    http://news.hexun.com/2019-05-13/197163407.html
# 1014    http://bank.hexun.com/2019-05-13/197164902.html
# 1015     http://iof.hexun.com/2019-05-13/197166361.html
# 1016    http://news.hexun.com/2019-05-13/197166246.html
# 1017    http://news.hexun.com/2019-05-13/197166241.html
# 1018    http://bank.hexun.com/2019-05-13/197170282.html
# 1019    http://news.hexun.com/2019-05-13/197170736.html
# 1020    http://news.hexun.com/2019-05-13/197171312.html
# 1021    http://news.hexun.com/2019-05-13/197170557.html
# 1022    http://news.hexun.com/2019-05-13/197171224.html
# 1023  http://www.pbc.gov.cn/zhengcehuobisi/125207/12...
# 1024     http://p2p.hexun.com/2019-05-13/197172602.html
# 1025    http://news.hexun.com/2019-05-13/197172500.html
# 1026    http://news.hexun.com/2019-05-13/197172258.html
# 1027    http://news.hexun.com/2019-05-13/197171808.html
# 1028    http://news.hexun.com/2019-05-13/197171984.html
#
# [1029 rows x 12 columns]

# %% [markdown]
# ## 删除zixun数据库

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient
import matplotlib.pyplot as plt  
#from wordcloud import WordCloud  
#import jieba
#import jieba.analyse
  


client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')

db = client.zixun
collection = db.zixun

#collection.remove()
stop
collection.remove({ "$and":[{'爬取日期':{'$lte':'2019-04-20'}} ] })  #自己的文章，爬取日期为空，所以不是被删掉
#collection.remove({'网站':{'$regex':'交易云'}})
# Out:
# 已经收集的日期有：
# ['2019-04-26', '2019-04-30', '2019-05-05']
# 最近日期：
# 2019-05-05
# 上一日期：
# 2019-04-30
#
#
#
#
# 余额总共新增：71.88719341230001 亿元
#               客户名称     生效截至日  2019-05-05  2019-05-05变动
# 0       招商银行股份有限公司  20190930       24.99         23.50
# 1     中国农业银行股份有限公司  20190930       21.70          9.16
# 2     中国工商银行股份有限公司  20190930       18.24          6.87
# 3       中国银行股份有限公司  20190930       14.71          4.83
# 4     中国石化财务有限责任公司  20190731       24.14          4.27
# 5     中国建设银行股份有限公司  20190930       19.42          3.87
# 6       广州银行股份有限公司  20190930        5.90          3.57
# 7     中国民生银行股份有限公司  20190930        2.78          2.78
# 8       浙商银行股份有限公司  20190930        9.07          2.71
# 9   上海浦东发展银行股份有限公司  20190930       12.06          2.57
# 10      中原银行股份有限公司  20191231        7.67          2.33
# 11      平安银行股份有限公司  20190930       28.54          1.78
# 12      晋城银行股份有限公司  20190831        1.70          1.69
# 13      北京银行股份有限公司  20191130        4.55          1.65
# 14        国投财务有限公司  20190930        9.20          1.26
#
#
#               客户名称     生效截至日  2019-05-05  2019-05-05变动
# 389     昆仑银行股份有限公司  20190930        0.00         -0.22
# 390     赣州银行股份有限公司  20191031        0.08         -0.31
# 391    平顶山银行股份有限公司  20191130        0.20         -0.38
# 392     上海银行股份有限公司  20191030        0.28         -0.42
# 393    哈尔滨银行股份有限公司  20190930        0.65         -0.51
# 394     齐鲁银行股份有限公司  20191031        0.06         -0.62
# 395  威海市商业银行股份有限公司  20191130        0.05         -0.66
# 396     盛京银行股份有限公司  20191231        0.01         -0.75
# 397     宁波银行股份有限公司  20190930        0.99         -0.76
# 398     桂林银行股份有限公司  20191130        0.02         -0.77
# 399     洛阳银行股份有限公司  20191130        0.04         -0.92
# 400   江苏苏宁银行股份有限公司  20200229        0.00         -0.93
# 401     泰安银行股份有限公司  20191031        0.00         -1.31
# 402     杭州银行股份有限公司  20190930        0.23         -1.79
# 403     渤海银行股份有限公司  20190930        0.06         -2.48

# %% [markdown]
# ## 从csv导入到zixun数据库

# %%
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')

#client = MongoClient()
#client = MongoClient('139.196.79.93', 27017)  #建立连接

#db=client.authenticate("root","5768116",mechanism="SCRAM-SHA-1").piao
db = client.zixun           #得到数据库
#db.authenticate("admin", "5768116")
collection = db.zixun      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='zixun.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print (df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print (df2)

#post = {"author": "Mike33", "text": "My first blog post!","tags": ["mongodb", "python", "pymongo"],"date": datetime.datetime.utcnow()}
#posts = db.posts
#post_id = posts.insert_one(post).inserted_id
#print post_id
#print posts.find_one()
#print posts.find_one({"author": "Mike33"})
#print posts.count()
#print post.find()

# %% [markdown]
# ## 读取zixun_jiaoyiyun数据库

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient
import matplotlib.pyplot as plt  
#from wordcloud import WordCloud  
#import jieba
#import jieba.analyse
  


client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')

db = client.zixun
collection = db.zixun

#cursor = collection.find({'标题':{'$regex':'ABS'}}) 

#cursor = collection.find({'爬取日期':{'$gte':'2018-05-01'}})
cursor = collection.find({'网站':'交易云'}) 
#cursor = collection.find({'爬取日期':None})
#cursor = collection.find()

zixun_df= pd.DataFrame(list(cursor))

print(zixun_df)




zixun_df.to_csv('jiaoyiyun.csv',encoding='GB18030',mode='w',header=True)

#collection.remove({'爬取日期':{'$lte':'2017-12-01'}})

# %% [markdown]
# ## 删除zixun_jiaoyiyun数据库

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient
import matplotlib.pyplot as plt  
#from wordcloud import WordCloud  
#import jieba
#import jieba.analyse
  


client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')

db = client.zixun
collection = db.zixun

#collection.remove({'爬取日期':{'$lte':'2018-04-20'}})
stop
collection.remove({'网站':'交易云'})  #自己的文章，爬取日期为空，所以不是被删掉
#collection.remove({'网站':{'$regex':'交易云'}})

# %% [markdown]
# ## 从csv导入到zixun_jiaoyiyun数据库

# %%
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')

#client = MongoClient()
#client = MongoClient('139.196.79.93', 27017)  #建立连接

#db=client.authenticate("root","5768116",mechanism="SCRAM-SHA-1").piao
db = client.zixun           #得到数据库
#db.authenticate("admin", "5768116")
collection = db.zixun      #得到数据集合


#df = read_mongo(db, 'collection')
#df = pd.DataFrame.from_dict({u'时间': {datetime.datetime.now()},u'交易对手':{111}})
url='jiaoyiyun.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print (df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print (df2)

#post = {"author": "Mike33", "text": "My first blog post!","tags": ["mongodb", "python", "pymongo"],"date": datetime.datetime.utcnow()}
#posts = db.posts
#post_id = posts.insert_one(post).inserted_id
#print post_id
#print posts.find_one()
#print posts.find_one({"author": "Mike33"})
#print posts.count()
#print post.find()

# %% [markdown]
# # pachong数据库

# %% [markdown]
# ##  读取pachong数据库

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient




client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
#client = MongoClient('139.196.79.93', 27017)
db = client.pachong
collection = db.pachong
    
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))


print(df2)

# %% [markdown]
# ## 删除pachong数据库

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient




client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
#client = MongoClient('139.196.79.93', 27017)
db = client.pachong
collection = db.pachong
# Make a query to the specific DB and Collection
collection.remove()

# %% [markdown]
# ## 从csv导入到pachong数据库

# %%
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')

db = client.pachong           #得到数据库

collection = db.pachong      #得到数据集合


url='pachong.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print (df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print (df2)

# %% [markdown]
# # pachong_guo数据库

# %% [markdown]
# ## 读取pachong_guo数据库

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient




client = MongoClient()
client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')
#client = MongoClient('139.196.79.93', 27017)
db = client.pachong_guo
collection = db.pachong_guo
    
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))


print(df2)

# %% [markdown]
# ## 删除pachong_guo数据库

# %%
# -*- coding: cp936 -*-
import datetime
import json,csv,re
import pandas as pd
from pymongo import MongoClient




client=MongoClient('mongodb://root:' + '5768116' + '@139.196.79.93')
#client = MongoClient('139.196.79.93', 27017)
db = client.pachong_guo
collection = db.pachong_guo
# Make a query to the specific DB and Collection
collection.remove()

# %% [markdown]
# ## 从csv导入到pachong_guo数据库

# %%
import datetime
import json,csv
import pandas as pd

from pymongo import MongoClient
client=MongoClient('mongodb://root:' + '5768116' + '@121.196.220.14')

db = client.pachong_guo          #得到数据库

collection = db.pachong_guo      #得到数据集合


url='pachong-guo.csv'
df = pd.read_table(url,sep=',',encoding='GB18030')   #用dictreader根据行内容查找

print (df)      
#print collection
records = json.loads(df.T.to_json()).values()
collection.insert(records)

    # Make a query to the specific DB and Collection
cursor = collection.find()
df2 = pd.DataFrame(list(cursor))
print (df2)
