# %% [markdown]
# # 1.清单计算

# %%
import csv,xlrd,xlwt,datetime,time,re
import numpy as np

import pandas as pd


#一、导入指导价

#二、打开对方清单
def suanqingdan():
    suanqingdan=0
    global url
    jia_df=pd.read_excel('D:/20190409部分/20180929桌面备份/报买断业务/转贴现买断价格计算/jia.xls',encoding='GB18030')
   # print('D:\20190409部分\20180929桌面备份\报买断业务\转贴现买断价格计算\jia.xls')
    shijian0=time.strftime('%Y-%m-%d',time.localtime(time.time()))
    shijian=datetime.datetime.strptime(shijian0 , "%Y-%m-%d")#转为日期格式

#2.1输入交易日
    jin=input('请输入要交易日,输入格式为“2017-11-01”，不输入默认为今天:')
    if jin!='':
        shijian=datetime.datetime.strptime(jin , "%Y-%m-%d")
    jia_df['生效截至日'] = pd.to_datetime(jia_df['生效截至日'])#.astype('str')   #,format='%Y%m%d'  吧yyyy-m-d 转化为yyyy-mm-dd的时间格式 注意要换成string格式
    jia_df=jia_df[((jia_df['生效截至日']>=shijian) | (jia_df['生效截至日']==''))&(jia_df['银行分类']!='BBB-及以下银行')]
    print(jia_df)
    jia_df= jia_df.reset_index(drop=True)    #重新定义索引
    qixian1=jia_df.columns[2].split('至')
    qixian2=jia_df.columns[3].split('至')
    qixian3=jia_df.columns[4].split('至')
    qixian4=jia_df.columns[5].split('至')
    qixian5=jia_df.columns[6].split('至')

    qixian1[0] = datetime.datetime.strptime(qixian1[0] , "%Y-%m-%d")
    qixian1[1] = datetime.datetime.strptime(qixian1[1] , "%Y-%m-%d")
    qixian2[0] = datetime.datetime.strptime(qixian2[0] , "%Y-%m-%d")
    qixian2[1] = datetime.datetime.strptime(qixian2[1] , "%Y-%m-%d")
    qixian3[0] = datetime.datetime.strptime(qixian3[0] , "%Y-%m-%d")
    qixian3[1] = datetime.datetime.strptime(qixian3[1] , "%Y-%m-%d")
    qixian4[0] = datetime.datetime.strptime(qixian4[0] , "%Y-%m-%d")
    qixian4[1] = datetime.datetime.strptime(qixian4[1] , "%Y-%m-%d")
    qixian5[0] = datetime.datetime.strptime(qixian5[0] , "%Y-%m-%d")
    qixian5[1] = datetime.datetime.strptime(qixian5[1] , "%Y-%m-%d")


#2.2确认列名，到时候可以删除
    jixu=input('请价差列名是否有：出票日（日期格式）、承兑行、承兑行号、到期日（日期格式）、票面金额、票号，请回车确认:')
    if jixu!='':
        stop
    qing=pd.read_excel(url)

    print(qing)
#二、换列标题
    qingcolumn=qing.columns.values.tolist()  
    qingcolumn_df=pd.read_excel('D:/20190409部分/20180929桌面备份/报买断业务/转贴现买断价格计算/lieming.csv',encoding='GB18030')
    for i in range(0,len(qingcolumn)):
        for j in range(0,len(qingcolumn_df)):
            zhaop2= re.search(qingcolumn_df.loc[j,'原列名'] ,qingcolumn[i])
 
            if zhaop2:
                qing.rename(columns={qingcolumn[i]:qingcolumn_df.loc[j,'新列名']}, inplace=True)
                
                break

    if '贴现行' not in qing.columns.values.tolist():
        qing['贴现行']=''


#三、筛选列，计算清单
    qing=qing[['票号','票面金额','出票人','承兑行','贴现行','出票日','到期日']]
    qing= qing.reset_index(drop=True)    #重新定义索引
    for i in range(0,len(qing)):
        qing.loc[i,'承兑行号']=str(qing.loc[i,'票号'])[1:13]
    print(qing)
    qing['到期日2'] = pd.to_datetime(qing['到期日'])   #把str转化为时间格式，format='%Y%m%d'  吧yyyy-m-d 转化为yyyy-mm-dd的时间格式
    qing= qing.reset_index(drop=True)    #重新定义索引
    qing['承兑行号']=qing['承兑行号'].astype(str)
    qing['出票日']=qing['出票日'].astype(str)
    qing['到期日']=qing['到期日'].astype(str)

    for i in range (0,len(qing)):     
         if (qing.loc[i,'到期日2']>=qixian1[0]) and (qing.loc[i,'到期日2']<=qixian1[1]) :
           for j in range (0,len(jia_df)):
               if (jia_df.loc[j,'银行类型'] in qing.loc[i,'承兑行']) and (float(jia_df.loc[j,jia_df.columns[2]])>=1) :
                   qing.loc[i,'邮储指导价']=jia_df.loc[j,jia_df.columns[2]]
                   qing.loc[i,'指导期限']=jia_df.columns[2]
                   qing.loc[i,'银行分类']=jia_df.loc[j,'银行分类']
               
                   qing.loc[i,'交易日']=str(shijian)
                   qing.loc[i,'交易日']=qing.loc[i,'交易日'].replace(' 00:00:00','')
                   qing.loc[i,'出票日']=qing.loc[i,'出票日'].replace(' 00:00:00','')
                   qing.loc[i,'到期日']=qing.loc[i,'到期日'].replace(' 00:00:00','')
                   qing.loc[i,'到期月']=qing.loc[i,'到期日'][:(len(qing.loc[i,'到期日'])-3)]

                   qing.loc[i,'承兑行号']=qing.loc[i,'承兑行号'].replace('.0','')

                   shijiancha=str(qing.loc[i,'到期日2']-shijian) #转化为str
                   shijiancha=int(shijiancha.replace(' days 00:00:00',''))  #转化为int
                   qing.loc[i,'期限']=shijiancha
                   qing.loc[i,'ji1']=shijiancha*qing.loc[i,'票面金额']
                   qing.loc[i,'ji2']=shijiancha*qing.loc[i,'票面金额']*qing.loc[i,'邮储指导价']
                   qing.loc[i,'可用额度']=jia_df.loc[j,'可用额度']
                   qing.loc[i,'生效截至日']=jia_df.loc[j,'生效截至日']
                   qing.loc[i,'授信有效']=jia_df.loc[j,'授信有效']
                   qing.loc[i,'我行评级']=jia_df.loc[j,'我行评级']
                   suanqingdan=suanqingdan+1

         elif (qing.loc[i,'到期日2']>=qixian2[0]) and (qing.loc[i,'到期日2']<=qixian2[1]) :

           for j in range (0,len(jia_df)):

               if jia_df.loc[j,'银行类型'] in qing.loc[i,'承兑行']    and (float(jia_df.loc[j,jia_df.columns[3]])>=1) :
                   
                   qing.loc[i,'邮储指导价']=jia_df.loc[j,jia_df.columns[3]]
                   qing.loc[i,'指导期限']=jia_df.columns[3]
                   qing.loc[i,'银行分类']=jia_df.loc[j,'银行分类']
                   qing.loc[i,'交易日']=str(shijian)
                   qing.loc[i,'交易日']=qing.loc[i,'交易日'].replace(' 00:00:00','')
                   qing.loc[i,'出票日']=qing.loc[i,'出票日'].replace(' 00:00:00','')
                   qing.loc[i,'到期日']=qing.loc[i,'到期日'].replace(' 00:00:00','')
                   qing.loc[i,'到期月']=qing.loc[i,'到期日'][:(len(qing.loc[i,'到期日'])-3)]
                   qing.loc[i,'承兑行号']=qing.loc[i,'承兑行号'].replace('.0','')
                   shijiancha=str(qing.loc[i,'到期日2']-shijian) #转化为str
                   shijiancha=int(shijiancha.replace(' days 00:00:00',''))  #转化为int
                   qing.loc[i,'期限']=shijiancha
                   qing.loc[i,'ji1']=shijiancha*qing.loc[i,'票面金额']
                   qing.loc[i,'ji2']=shijiancha*qing.loc[i,'票面金额']*qing.loc[i,'邮储指导价']
                   qing.loc[i,'可用额度']=jia_df.loc[j,'可用额度']
                   qing.loc[i,'生效截至日']=jia_df.loc[j,'生效截至日']
                   qing.loc[i,'授信有效']=jia_df.loc[j,'授信有效']
                   qing.loc[i,'我行评级']=jia_df.loc[j,'我行评级']
                   suanqingdan=suanqingdan+1

         elif (qing.loc[i,'到期日2']>=qixian3[0]) and (qing.loc[i,'到期日2']<=qixian3[1])  :  #

           for j in range (0,len(jia_df)):
               if jia_df.loc[j,'银行类型'] in qing.loc[i,'承兑行']  and (float(jia_df.loc[j,jia_df.columns[4]])>=1):
                   qing.loc[i,'邮储指导价']=jia_df.loc[j,jia_df.columns[4]]

                   qing.loc[i,'指导期限']=jia_df.columns[4]
                   qing.loc[i,'银行分类']=jia_df.loc[j,'银行分类']
                   qing.loc[i,'交易日']=str(shijian)
                   qing.loc[i,'交易日']=qing.loc[i,'交易日'].replace(' 00:00:00','')
                   qing.loc[i,'出票日']=qing.loc[i,'出票日'].replace(' 00:00:00','')
                   qing.loc[i,'到期日']=qing.loc[i,'到期日'].replace(' 00:00:00','')
                   qing.loc[i,'到期月']=qing.loc[i,'到期日'][:(len(qing.loc[i,'到期日'])-3)]

                   qing.loc[i,'承兑行号']=qing.loc[i,'承兑行号'].replace('.0','')
               
                   shijiancha=str(qing.loc[i,'到期日2']-shijian) #转化为str
                   shijiancha=int(shijiancha.replace(' days 00:00:00',''))  #转化为int
                   qing.loc[i,'期限']=shijiancha
                   qing.loc[i,'ji1']=shijiancha*qing.loc[i,'票面金额']
                   qing.loc[i,'ji2']=shijiancha*qing.loc[i,'票面金额']*qing.loc[i,'邮储指导价']
                   qing.loc[i,'可用额度']=jia_df.loc[j,'可用额度']
                   qing.loc[i,'生效截至日']=jia_df.loc[j,'生效截至日']
                   qing.loc[i,'授信有效']=jia_df.loc[j,'授信有效']
                   qing.loc[i,'我行评级']=jia_df.loc[j,'我行评级']
                   suanqingdan=suanqingdan+1

         elif (qing.loc[i,'到期日2']>=qixian4[0]) and (qing.loc[i,'到期日2']<=qixian4[1])  :

           for j in range (0,len(jia_df)) :
               if jia_df.loc[j,'银行类型'] in qing.loc[i,'承兑行'] and (float(jia_df.loc[j,jia_df.columns[5]])>=1):
                   qing.loc[i,'邮储指导价']=jia_df.loc[j,jia_df.columns[5]]
                   qing.loc[i,'指导期限']=jia_df.columns[5]
                   qing.loc[i,'银行分类']=jia_df.loc[j,'银行分类']
                   qing.loc[i,'交易日']=str(shijian)
                   qing.loc[i,'交易日']=qing.loc[i,'交易日'].replace(' 00:00:00','')
                   qing.loc[i,'出票日']=qing.loc[i,'出票日'].replace(' 00:00:00','')
                   qing.loc[i,'到期日']=qing.loc[i,'到期日'].replace(' 00:00:00','')
                   qing.loc[i,'到期月']=qing.loc[i,'到期日'][:(len(qing.loc[i,'到期日'])-3)]

                   qing.loc[i,'承兑行号']=qing.loc[i,'承兑行号'].replace('.0','')
               
                   shijiancha=str(qing.loc[i,'到期日2']-shijian) #转化为str
                   shijiancha=int(shijiancha.replace(' days 00:00:00',''))  #转化为int
                   qing.loc[i,'期限']=shijiancha
                   qing.loc[i,'ji1']=shijiancha*qing.loc[i,'票面金额']
                   qing.loc[i,'ji2']=shijiancha*qing.loc[i,'票面金额']*qing.loc[i,'邮储指导价']
                   qing.loc[i,'可用额度']=jia_df.loc[j,'可用额度']
                   qing.loc[i,'生效截至日']=jia_df.loc[j,'生效截至日']
                   qing.loc[i,'授信有效']=jia_df.loc[j,'授信有效']
                   qing.loc[i,'我行评级']=jia_df.loc[j,'我行评级']
                   suanqingdan=suanqingdan+1




         elif (qing.loc[i,'到期日2']>=qixian5[0]) and (qing.loc[i,'到期日2']<=qixian5[1])  :

           for j in range (0,len(jia_df)) :
               if jia_df.loc[j,'银行类型'] in qing.loc[i,'承兑行'] and (float(jia_df.loc[j,jia_df.columns[6]])>=1):
                   qing.loc[i,'邮储指导价']=jia_df.loc[j,jia_df.columns[6]]
                   qing.loc[i,'指导期限']=jia_df.columns[6]
                   qing.loc[i,'银行分类']=jia_df.loc[j,'银行分类']
                   qing.loc[i,'交易日']=str(shijian)
                   qing.loc[i,'交易日']=qing.loc[i,'交易日'].replace(' 00:00:00','')
                   qing.loc[i,'出票日']=qing.loc[i,'出票日'].replace(' 00:00:00','')
                   qing.loc[i,'到期日']=qing.loc[i,'到期日'].replace(' 00:00:00','')
                   qing.loc[i,'到期月']=qing.loc[i,'到期日'][:(len(qing.loc[i,'到期日'])-3)]

                   qing.loc[i,'承兑行号']=qing.loc[i,'承兑行号'].replace('.0','')
               
                   shijiancha=str(qing.loc[i,'到期日2']-shijian) #转化为str
                   shijiancha=int(shijiancha.replace(' days 00:00:00',''))  #转化为int
                   qing.loc[i,'期限']=shijiancha
                   qing.loc[i,'ji1']=shijiancha*qing.loc[i,'票面金额']
                   qing.loc[i,'ji2']=shijiancha*qing.loc[i,'票面金额']*qing.loc[i,'邮储指导价']
                   qing.loc[i,'可用额度']=jia_df.loc[j,'可用额度']
                   qing.loc[i,'生效截至日']=jia_df.loc[j,'生效截至日']
                   qing.loc[i,'授信有效']=jia_df.loc[j,'授信有效']
                   qing.loc[i,'我行评级']=jia_df.loc[j,'我行评级']
                   suanqingdan=suanqingdan+1
                   
    if suanqingdan<=0:
        print('整个清单都不能收！')
    else:
        qing['加权利率']=qing.loc[:,'ji2'].sum()/qing.loc[:,'ji1'].sum()
        del qing['到期日2']



        qing=qing[['票号','票面金额','出票人','承兑行','承兑行号','出票日','到期日','交易日','银行分类','邮储指导价','指导期限','加权利率','贴现行','可用额度','我行评级','生效截至日','授信有效','期限','到期月']]
#三、将算好的清单写入excel
        qing2=qing.replace(np.nan,99)
        print(qing2)
        qing2=qing2[qing2['邮储指导价'] != 99]  #排除NAN
        chengdui=qing2['票面金额'].groupby(qing2['银行分类']).sum()/10000
        print('  ')

        zongjin=qing2['票面金额'].sum()/10000
        print('总金额：%s'%zongjin)
        print('  清单分类如下：')

        print(chengdui)
        print('  ')
        yuefen=qing2['票面金额'].groupby(qing2['到期月']).sum()/10000
        print(yuefen)
        print('  ')
        qixian=qing2['期限'].mean()
        print(qixian)
        print('  ')


    
    
        url2='D:/20190409部分/20180929桌面备份/报买断业务/临时清单/'+shijian0+duifang+'算加权.xls'
        writer = pd.ExcelWriter(url2)
        qing.to_excel(writer,'Sheet1')
        writer.save()





#四、制作导
        qing2['导汇票']=1
        qing2['导出票人账号']=''
        qing2['导收款人名称']=''
        qing2['导1']=''
        qing2['导2']=''
        qing2['导3']=''
        qing2['同城']=1
        qing2=qing2[['导汇票','票号','票面金额','出票日','到期日','出票人','导出票人账号','承兑行号','承兑行','导收款人名称','导1','导2','导3','承兑行号','同城','交易日','期限']]



        url3='D:/20190409部分/20180929桌面备份/报买断业务/临时清单/'+shijian0+duifang+'导入.xls'
        writer = pd.ExcelWriter(url3)
        qing2.to_excel(writer,'Sheet1')
        writer.save()

for i in range(0,1):
    duifang=input('请输入文件名：')
 #   duifang=''+duifang
    url=('D:/20190409部分/20180929桌面备份/报买断业务/临时清单/%s'%duifang)
    if duifang=='':
        continue
    else:
        suanqingdan()
# Out:
# 请输入文件名：年内电银(1)(1).xlsx
# 请输入要交易日,输入格式为“2017-11-01”，不输入默认为今天:
#            银行类型    银行分类  2019-01-01至2019-03-29  2019-04-01至2019-08-31  \
# 0      上海浦东发展银行      国股                      3                      3
# 1            浦发      国股                      3                      3
# 2          兴业银行      国股                      3                      3
# 3          华夏银行      国股                      3                      3
# 4          工商银行      国股                      3                      3
# 5            农行      国股                      3                      3
# 6          农业银行      国股                      3                      3
# 7        农业发展银行      国股                      3                      3
# 8          中国银行      国股                      3                      3
# 9          建设银行      国股                      3                      3
# 10         交通银行      国股                      3                      3
# 11         光大银行      国股                      3                      3
# 12         招商银行      国股                      3                      3
# 13         民生银行      国股                      3                      3
# 14         中信银行      国股                      3                      3
# 15         平安银行      国股                      3                      3
# 16       邮政储蓄银行      国股                      3                      3
# 17         广发银行      国股                      3                      3
# 18       国家开发银行      国股                      3                      3
# 19      中国进出口银行      国股                      3                      3
# 20         浙商银行      大商                      3                      3
# 21         北京银行      大商                      3                      3
# 22         上海银行      大商                      3                      3
# 23         江苏银行      大商                      3                      3
# 24         南京银行      大商                      3                      3
# 25         宁波银行      大商                      3                      3
# 26         渤海银行    一类准入                      3                      3
# 27         徽商银行    一类准入                      3                      3
# 28         杭州银行    一类准入                      3                      3
# 29         重庆农商    一类准入                      3                      3
# ..          ...     ...                    ...                    ...
# 281        晋城银行  其他授信银行                      3                      3
# 282      鄂尔多斯银行  其他授信银行                      3                      3
# 283      珠海华润银行  其他授信银行                      3                      3
# 284     宜宾市商业银行  其他授信银行                      3                      3
# 285        晋中银行  其他授信银行                      3                      3
# 286        嘉兴银行  其他授信银行                      3                      3
# 287       福建南安农  其他授信银行                      3                      3
# 288        自贡银行  其他授信银行                      3                      3
# 289    浙江稠州商业银行  其他授信银行                      3                      3
# 290         长春农  其他授信银行                      3                      3
# 291       内蒙古银行  其他授信银行                      3                      3
# 292       石嘴山银行  其他授信银行                      3                      3
# 293         南昌农  其他授信银行                      3                      3
# 294        衡水银行  其他授信银行                      3                      3
# 295        日照银行  其他授信银行                      3                      3
# 296        绍兴银行  其他授信银行                      3                      3
# 297        柳州银行  其他授信银行                      3                      3
# 298        承德银行  其他授信银行                      3                      3
# 299      民生金融租赁  其他授信银行                      3                      3
# 302      广东南粤银行  其他授信银行                      3                      3
# 307        龙江银行  其他授信银行                      3                      3
# 308       浙江义乌农  其他授信银行                      3                      3
# 309       天津滨海农  其他授信银行                      3                      3
# 310    浙江民泰商业银行  其他授信银行                      3                      3
# 314       江苏民丰农  其他授信银行                      3                      3
# 319       江苏南通农  其他授信银行                      3                      3
# 329      浙江网商银行  其他授信银行                      3                      3
# 331     浙江温州龙湾农  其他授信银行                      3                      3
# 332      中信百信银行  其他授信银行                      3                      3
# 334  朝阳银行股份有限公司  其他授信银行                      3                      3
#
#      2019-09-01至2019-09-30  2019-10-01至2019-12-29  2020-01-01至2020-12-30 授信有效  \
# 0                     3.30                   3.30                   3.32   有效
# 1                     3.30                   3.30                   3.32   有效
# 2                     3.30                   3.30                   3.32   有效
# 3                     3.30                   3.30                   3.32   有效
# 4                     3.30                   3.30                   3.32   有效
# 5                     3.30                   3.30                   3.32   有效
# 6                     3.30                   3.30                   3.32   有效
# 7                     3.30                   3.30                   3.32   有效
# 8                     3.30                   3.30                   3.32   有效
# 9                     3.30                   3.30                   3.32   有效
# 10                    3.30                   3.30                   3.32   有效
# 11                    3.30                   3.30                   3.32   有效
# 12                    3.30                   3.30                   3.32   有效
# 13                    3.30                   3.30                   3.32   有效
# 14                    3.30                   3.30                   3.32   有效
# 15                    3.30                   3.30                   3.32   有效
# 16                    3.30                   3.30                   3.32   有效
# 17                    3.30                   3.30                   3.32   有效
# 18                    3.30                   3.30                   3.32   有效
# 19                    3.30                   3.30                   3.32   有效
# 20                    3.33                   3.33                   3.35   有效
# 21                    3.33                   3.33                   3.35   有效
# 22                    3.33                   3.33                   3.35   有效
# 23                    3.33                   3.33                   3.35   有效
# 24                    3.33                   3.33                   3.35   有效
# 25                    3.33                   3.33                   3.35   有效
# 26                    3.36                   3.36                   3.38   有效
# 27                    3.36                   3.36                   3.38   有效
# 28                    3.36                   3.36                   3.38   有效
# 29                    3.36                   3.36                   3.38   有效
# ..                     ...                    ...                    ...  ...
# 281                   3.50                   3.50                   3.52   有效
# 282                   3.50                   3.50                   3.52   有效
# 283                   3.50                   3.50                   3.52   有效
# 284                   3.50                   3.50                   3.52   有效
# 285                   3.50                   3.50                   3.52   有效
# 286                   3.50                   3.50                   3.52   有效
# 287                   3.50                   3.50                   3.52   有效
# 288                   3.50                   3.50                   3.52   有效
# 289                   3.50                   3.50                   3.52   有效
# 290                   3.50                   3.50                   3.52   有效
# 291                   3.50                   3.50                   3.52   有效
# 292                   3.50                   3.50                   3.52   有效
# 293                   3.50                   3.50                   3.52   有效
# 294                   3.50                   3.50                   3.52   有效
# 295                   3.50                   3.50                   3.52   有效
# 296                   3.50                   3.50                   3.52   有效
# 297                   3.50                   3.50                   3.52   有效
# 298                   3.50                   3.50                   3.52   有效
# 299                   3.50                   3.50                   3.52   有效
# 302                   3.50                   3.50                   3.52   有效
# 307                   3.50                   3.50                   3.52   有效
# 308                   3.50                   3.50                   3.52   有效
# 309                   3.50                   3.50                   3.52   有效
# 310                   3.50                   3.50                   3.52   有效
# 314                   3.50                   3.50                   3.52   有效
# 319                   3.50                   3.50                   3.52   有效
# 329                   3.50                   3.50                   3.52   有效
# 331                   3.50                   3.50                   3.52   有效
# 332                   3.50                   3.50                   3.52   有效
# 334                   3.50                   3.50                   3.52   有效
#
#              可用额度      生效截至日  我行评级   更新  贴现行
# 0    1.380453e+04 2019-07-17   AAA  1.0  NaN
# 1    2.287364e+04 2019-09-30   AAA  NaN  NaN
# 2    7.703118e+08 2019-09-02  AAA+  1.0  NaN
# 3    1.684744e+06 2019-09-02   AA-  1.0  NaN
# 4    9.659693e+09 2019-09-10  AAA+  1.0  NaN
# 5    1.624090e+10 2019-09-30  AAA+  NaN  NaN
# 6    9.659693e+09 2019-07-26  AAA+  1.0  NaN
# 7    1.624090e+10 2019-09-24   AAA  1.0  NaN
# 8    2.686689e+09 2019-06-04  AAA+  1.0  NaN
# 9    8.277712e+09 2019-06-10  AAA+  1.0  NaN
# 10   2.002856e+06 2019-08-12  AAA+  1.0  NaN
# 11   7.590464e+08 2019-08-12  AAA-  1.0  NaN
# 12   2.792610e+10 2019-08-07  AAA+  1.0  NaN
# 13   0.000000e+00 2019-09-10  AAA-  1.0  NaN
# 14   2.678253e+09 2019-09-10  AAA-  1.0  NaN
# 15   4.774596e+07 2019-07-26    AA  1.0  NaN
# 16   1.000000e+10 2019-09-30   NaN  NaN  NaN
# 17   4.798815e+09 2019-08-12    A-  1.0  NaN
# 18   8.725544e+09 2019-09-02   AAA  1.0  NaN
# 19   2.000000e+10 2019-10-22   AAA  1.0  NaN
# 20   5.050326e+07 2019-07-30    A+  1.0  NaN
# 21   5.169793e+09 2019-11-12    AA  1.0  NaN
# 22   2.835730e+09 2019-10-18    AA  1.0  NaN
# 23   7.262350e+04 2019-08-12   AA-  1.0  NaN
# 24   9.659778e+08 2019-09-20   AA-  1.0  NaN
# 25   1.854153e+05 2019-08-27    AA  1.0  NaN
# 26   7.344446e+05 2019-08-12     A  1.0  NaN
# 27   4.403999e+09 2019-06-27   AA-  1.0  NaN
# 28   3.275650e+07 2019-09-18   AA-  1.0  NaN
# 29   3.350540e+09 2019-09-30   NaN  NaN  NaN
# ..            ...        ...   ...  ...  ...
# 281  6.900000e+06 2019-08-27   BBB  1.0  NaN
# 282  1.000000e-02 2019-10-31   BBB  NaN  NaN
# 283  8.707632e+04 2019-09-28   BBB  1.0  NaN
# 284  2.515320e+07 2019-08-07   BBB  1.0  NaN
# 285  1.235053e+06 2019-08-12  BBB-  1.0  NaN
# 286  3.420949e+05 2019-06-27   BBB  1.0  NaN
# 287  4.377786e+07 2019-09-18  BBB-  1.0  NaN
# 288  4.398200e+05 2019-08-22   BBB  1.0  NaN
# 289  6.102533e+05 2019-10-23   BBB  1.0  NaN
# 290  6.000000e+06 2019-08-27   BBB  1.0  NaN
# 291  9.000000e+04 2019-11-07  BBB-  1.0  NaN
# 292  7.000000e+05 2019-10-31   BBB  NaN  NaN
# 293  1.199182e+08 2019-11-06   BBB  1.0  NaN
# 294  1.976667e+08 2019-07-30  BBB-  1.0  NaN
# 295  1.794369e+07 2019-10-31   BBB  1.0  NaN
# 296  1.906856e+08 2019-11-06  BBB-  1.0  NaN
# 297  1.000000e-02 2019-09-04  BBB-  1.0  NaN
# 298  4.765189e+08 2019-09-11    A-  1.0  NaN
# 299  1.000000e-02 2019-09-10   AA-  1.0  NaN
# 302  2.666970e+03 2019-12-06   BBB  1.0  NaN
# 307  1.057317e+08 2019-11-08    A-  1.0  NaN
# 308  4.525361e+07 2019-09-18    A-  1.0  NaN
# 309  1.345000e+09 2019-12-02  BBB-  1.0  NaN
# 310  0.000000e+00 2019-09-02   BBB  1.0  NaN
# 314  7.500000e+06 2019-09-29   BBB  1.0  NaN
# 319  2.000000e+08 2019-09-16  BBB+  1.0  NaN
# 329  1.310985e+08 2019-11-28   BBB  1.0  NaN
# 331  1.111111e+08 2019-12-23   BBB  1.0  NaN
# 332           NaN 2019-06-04  BBB-  NaN  NaN
# 334           NaN 2020-01-03    A-  1.0  NaN
#
# [265 rows x 13 columns]
# 请价差列名是否有：出票日（日期格式）、承兑行、承兑行号、到期日（日期格式）、票面金额、票号，请回车确认:
#                                 票号           金额        出票日      票面到期日  \
# 0   130758400866720190322366026515    439398.72 2019-03-22 2019-09-21
# 1   110458400230820190402373207070    356176.00 2019-04-02 2019-10-01
# 2   130858803711020190412377274553   5602500.00 2019-04-12 2019-10-12
# 3   131058100001720190417379910229   1648200.00 2019-04-17 2019-10-17
# 4   131058100001720190417379988140  10941000.00 2019-04-17 2019-10-24
# 5   131058100001720190417379988131   8640000.00 2019-04-17 2019-10-24
# 6   110231400600120190426386668048  12628254.26 2019-04-26 2019-10-25
# 7   130458404206120190403373450138   1200000.00 2019-04-03 2019-11-03
# 8   130658400014820181114287509381  10000000.00 2018-11-14 2019-11-14
# 9   110346305164120181123292948143    100000.00 2018-11-23 2019-11-23
# 10  130649100172020181227316320756   1000000.00 2018-12-27 2019-12-27
# 11  130529000239120181228317676560   8000000.00 2018-12-28 2019-12-28
# 12  131358400308720190402373277529   1500001.10 2019-04-02 2019-10-02
# 13  131358400400620190409375325090  10000000.00 2019-04-09 2019-10-08
# 14  131358400400620190409375325112  10000000.00 2019-04-09 2019-10-08
# 15  131679100002420181115288826890   1000000.00 2018-11-15 2019-11-15
# 16  131342842863620190403373597385    827850.00 2019-04-03 2019-10-03
# 17  131350200179020181108284880264     50000.00 2018-11-08 2019-11-06
# 18                             NaN  83933380.08        NaT        NaT
#
#          星期  节假日加天                    出票人                  收票人  \
# 0   43729.0    2.0           深圳创维数字技术有限公司     成都康特电子高新科技有限责任公司
# 1   43739.0    7.0            深圳市博源电子有限公司        深圳市天河星供应链有限公司
# 2   43750.0    0.0          佛山市国星光电股份有限公司       深圳市华腾半导体设备有限公司
# 3   43755.0    0.0           广州创显科教股份有限公司        广州市钻海智能技术有限公司
# 4   43762.0    0.0          广州市浪奇实业股份有限公司         深圳市合正荣实业有限公司
# 5   43762.0    0.0          广州市浪奇实业股份有限公司         深圳市合正荣实业有限公司
# 6   43763.0    0.0           孚能科技（镇江）有限公司        深圳市智佳能自动化有限公司
# 7   43772.0    1.0           中铁隧道集团三处有限公司        深圳市升航建筑材料有限公司
# 8   43783.0    0.0       深圳市新星轻合金材料股份有限公司       北方联合铝业（深圳）有限公司
# 9   43792.0    2.0  新汶矿业集团物资供销有限责任公司泰安分公司     新汶矿业集团物资供销有限责任公司
# 10  43826.0    0.0     濮阳濮耐高温材料（集团）股份有限公司         营口濮耐镁质材料有限公司
# 11  43827.0    2.0          上海市安装工程集团有限公司       北京启明信源电力工程有限公司
# 12  43740.0    6.0           深圳欣锐科技股份有限公司        深圳市天河星供应链有限公司
# 13  43746.0    0.0            欣旺达电子股份有限公司       深圳市欣旺达智能硬件有限公司
# 14  43746.0    0.0            欣旺达电子股份有限公司       深圳市欣旺达智能硬件有限公司
# 15  43784.0    0.0            银川隆基硅材料有限公司         亚洲硅业（青海）有限公司
# 16  43741.0    5.0         江西比亚迪电子部品件有限公司        深圳市天河星供应链有限公司
# 17  43775.0    0.0      濮阳市汇丰置业有限公司东湖湾分公司  河南豫安信息系统工程有限公司濮阳分公司
# 18      NaN    NaN                    NaN                  NaN
#
#                    承兑行
# 0          平安银行深圳香蜜湖支行
# 1     中国银行股份有限公司深圳福永支行
# 2     招商银行股份有限公司佛山平洲支行
# 3            浦发广州分行营业部
# 4            浦发广州分行营业部
# 5            浦发广州分行营业部
# 6   中国工商银行股份有限公司镇江新区支行
# 7     华夏银行股份有限公司深圳布吉支行
# 8          广发银行深圳分行营业部
# 9   中国农业银行股份有限公司泰安岱岳支行
# 10   广发银行股份有限公司郑州分行营业部
# 11    中国民生银行股份有限公司上海分行
# 12   宁波银行股份有限公司深圳财富港支行
# 13      杭州银行股份有限公司深圳分行
# 14      杭州银行股份有限公司深圳分行
# 15            浙商银行西安分行
# 16      赣州银行股份有限公司信丰支行
# 17      中原银行股份有限公司濮阳分行
# 18                 NaN
#                                 票号         票面金额                    出票人  \
# 0   130758400866720190322366026515    439398.72           深圳创维数字技术有限公司
# 1   110458400230820190402373207070    356176.00            深圳市博源电子有限公司
# 2   130858803711020190412377274553   5602500.00          佛山市国星光电股份有限公司
# 3   131058100001720190417379910229   1648200.00           广州创显科教股份有限公司
# 4   131058100001720190417379988140  10941000.00          广州市浪奇实业股份有限公司
# 5   131058100001720190417379988131   8640000.00          广州市浪奇实业股份有限公司
# 6   110231400600120190426386668048  12628254.26           孚能科技（镇江）有限公司
# 7   130458404206120190403373450138   1200000.00           中铁隧道集团三处有限公司
# 8   130658400014820181114287509381  10000000.00       深圳市新星轻合金材料股份有限公司
# 9   110346305164120181123292948143    100000.00  新汶矿业集团物资供销有限责任公司泰安分公司
# 10  130649100172020181227316320756   1000000.00     濮阳濮耐高温材料（集团）股份有限公司
# 11  130529000239120181228317676560   8000000.00          上海市安装工程集团有限公司
# 12  131358400308720190402373277529   1500001.10           深圳欣锐科技股份有限公司
# 13  131358400400620190409375325090  10000000.00            欣旺达电子股份有限公司
# 14  131358400400620190409375325112  10000000.00            欣旺达电子股份有限公司
# 15  131679100002420181115288826890   1000000.00            银川隆基硅材料有限公司
# 16  131342842863620190403373597385    827850.00         江西比亚迪电子部品件有限公司
# 17  131350200179020181108284880264     50000.00      濮阳市汇丰置业有限公司东湖湾分公司
# 18                             NaN  83933380.08                    NaN
#
#                    承兑行 贴现行        出票日        到期日          承兑行号
# 0          平安银行深圳香蜜湖支行     2019-03-22 2019-09-21  307584008667
# 1     中国银行股份有限公司深圳福永支行     2019-04-02 2019-10-01  104584002308
# 2     招商银行股份有限公司佛山平洲支行     2019-04-12 2019-10-12  308588037110
# 3            浦发广州分行营业部     2019-04-17 2019-10-17  310581000017
# 4            浦发广州分行营业部     2019-04-17 2019-10-24  310581000017
# 5            浦发广州分行营业部     2019-04-17 2019-10-24  310581000017
# 6   中国工商银行股份有限公司镇江新区支行     2019-04-26 2019-10-25  102314006001
# 7     华夏银行股份有限公司深圳布吉支行     2019-04-03 2019-11-03  304584042061
# 8          广发银行深圳分行营业部     2018-11-14 2019-11-14  306584000148
# 9   中国农业银行股份有限公司泰安岱岳支行     2018-11-23 2019-11-23  103463051641
# 10   广发银行股份有限公司郑州分行营业部     2018-12-27 2019-12-27  306491001720
# 11    中国民生银行股份有限公司上海分行     2018-12-28 2019-12-28  305290002391
# 12   宁波银行股份有限公司深圳财富港支行     2019-04-02 2019-10-02  313584003087
# 13      杭州银行股份有限公司深圳分行     2019-04-09 2019-10-08  313584004006
# 14      杭州银行股份有限公司深圳分行     2019-04-09 2019-10-08  313584004006
# 15            浙商银行西安分行     2018-11-15 2019-11-15  316791000024
# 16      赣州银行股份有限公司信丰支行     2019-04-03 2019-10-03  313428428636
# 17      中原银行股份有限公司濮阳分行     2018-11-08 2019-11-06  313502001790
# 18                 NaN            NaT        NaT            an
#                                 票号         票面金额                    出票人  \
# 0   130758400866720190322366026515    439398.72           深圳创维数字技术有限公司
# 1   110458400230820190402373207070    356176.00            深圳市博源电子有限公司
# 2   130858803711020190412377274553   5602500.00          佛山市国星光电股份有限公司
# 3   131058100001720190417379910229   1648200.00           广州创显科教股份有限公司
# 4   131058100001720190417379988140  10941000.00          广州市浪奇实业股份有限公司
# 5   131058100001720190417379988131   8640000.00          广州市浪奇实业股份有限公司
# 6   110231400600120190426386668048  12628254.26           孚能科技（镇江）有限公司
# 7   130458404206120190403373450138   1200000.00           中铁隧道集团三处有限公司
# 8   130658400014820181114287509381  10000000.00       深圳市新星轻合金材料股份有限公司
# 9   110346305164120181123292948143    100000.00  新汶矿业集团物资供销有限责任公司泰安分公司
# 10  130649100172020181227316320756   1000000.00     濮阳濮耐高温材料（集团）股份有限公司
# 11  130529000239120181228317676560   8000000.00          上海市安装工程集团有限公司
# 12  131358400308720190402373277529   1500001.10           深圳欣锐科技股份有限公司
# 13  131358400400620190409375325090  10000000.00            欣旺达电子股份有限公司
# 14  131358400400620190409375325112  10000000.00            欣旺达电子股份有限公司
# 15  131679100002420181115288826890   1000000.00            银川隆基硅材料有限公司
# 16  131342842863620190403373597385    827850.00         江西比亚迪电子部品件有限公司
# 17  131350200179020181108284880264     50000.00      濮阳市汇丰置业有限公司东湖湾分公司
# 18                              99  83933380.08                     99
#
#                    承兑行          承兑行号         出票日         到期日         交易日  \
# 0          平安银行深圳香蜜湖支行  307584008667  2019-03-22  2019-09-21  2019-05-06
# 1     中国银行股份有限公司深圳福永支行  104584002308  2019-04-02  2019-10-01  2019-05-06
# 2     招商银行股份有限公司佛山平洲支行  308588037110  2019-04-12  2019-10-12  2019-05-06
# 3            浦发广州分行营业部  310581000017  2019-04-17  2019-10-17  2019-05-06
# 4            浦发广州分行营业部  310581000017  2019-04-17  2019-10-24  2019-05-06
# 5            浦发广州分行营业部  310581000017  2019-04-17  2019-10-24  2019-05-06
# 6   中国工商银行股份有限公司镇江新区支行  102314006001  2019-04-26  2019-10-25  2019-05-06
# 7     华夏银行股份有限公司深圳布吉支行  304584042061  2019-04-03  2019-11-03  2019-05-06
# 8          广发银行深圳分行营业部  306584000148  2018-11-14  2019-11-14  2019-05-06
# 9   中国农业银行股份有限公司泰安岱岳支行  103463051641  2018-11-23  2019-11-23  2019-05-06
# 10   广发银行股份有限公司郑州分行营业部  306491001720  2018-12-27  2019-12-27  2019-05-06
# 11    中国民生银行股份有限公司上海分行  305290002391  2018-12-28  2019-12-28  2019-05-06
# 12   宁波银行股份有限公司深圳财富港支行  313584003087  2019-04-02  2019-10-02  2019-05-06
# 13      杭州银行股份有限公司深圳分行  313584004006  2019-04-09  2019-10-08  2019-05-06
# 14      杭州银行股份有限公司深圳分行  313584004006  2019-04-09  2019-10-08  2019-05-06
# 15            浙商银行西安分行  316791000024  2018-11-15  2019-11-15  2019-05-06
# 16      赣州银行股份有限公司信丰支行  313428428636  2019-04-03  2019-10-03  2019-05-06
# 17      中原银行股份有限公司濮阳分行  313502001790  2018-11-08  2019-11-06  2019-05-06
# 18                  99            an         NaT         NaT          99
#
#       银行分类  邮储指导价                   指导期限     加权利率 贴现行          可用额度  我行评级  \
# 0       国股   3.30  2019-09-01至2019-09-30  3.31526      4.774596e+07    AA
# 1       国股   3.30  2019-10-01至2019-12-29  3.31526      2.686689e+09  AAA+
# 2       国股   3.30  2019-10-01至2019-12-29  3.31526      2.792610e+10  AAA+
# 3       国股   3.30  2019-10-01至2019-12-29  3.31526      2.287364e+04   AAA
# 4       国股   3.30  2019-10-01至2019-12-29  3.31526      2.287364e+04   AAA
# 5       国股   3.30  2019-10-01至2019-12-29  3.31526      2.287364e+04   AAA
# 6       国股   3.30  2019-10-01至2019-12-29  3.31526      9.659693e+09  AAA+
# 7       国股   3.30  2019-10-01至2019-12-29  3.31526      1.684744e+06   AA-
# 8       国股   3.30  2019-10-01至2019-12-29  3.31526      4.798815e+09    A-
# 9       国股   3.30  2019-10-01至2019-12-29  3.31526      9.659693e+09  AAA+
# 10      国股   3.30  2019-10-01至2019-12-29  3.31526      4.798815e+09    A-
# 11      国股   3.30  2019-10-01至2019-12-29  3.31526      0.000000e+00  AAA-
# 12      大商   3.33  2019-10-01至2019-12-29  3.31526      1.854153e+05    AA
# 13    一类准入   3.36  2019-10-01至2019-12-29  3.31526      3.275650e+07   AA-
# 14    一类准入   3.36  2019-10-01至2019-12-29  3.31526      3.275650e+07   AA-
# 15      大商   3.33  2019-10-01至2019-12-29  3.31526      5.050326e+07    A+
# 16  其他授信银行   3.50  2019-10-01至2019-12-29  3.31526      3.134584e+06  BBB+
# 17    二类准入   3.45  2019-10-01至2019-12-29  3.31526      9.490792e+08    A+
# 18      99  99.00                     99  3.31526      9.900000e+01    99
#
#                   生效截至日 授信有效     期限      到期月
# 0   2019-07-26 00:00:00   有效  138.0  2019-09
# 1   2019-06-04 00:00:00   有效  148.0  2019-10
# 2   2019-08-07 00:00:00   有效  159.0  2019-10
# 3   2019-09-30 00:00:00   有效  164.0  2019-10
# 4   2019-09-30 00:00:00   有效  171.0  2019-10
# 5   2019-09-30 00:00:00   有效  171.0  2019-10
# 6   2019-09-10 00:00:00   有效  172.0  2019-10
# 7   2019-09-02 00:00:00   有效  181.0  2019-11
# 8   2019-08-12 00:00:00   有效  192.0  2019-11
# 9   2019-07-26 00:00:00   有效  201.0  2019-11
# 10  2019-08-12 00:00:00   有效  235.0  2019-12
# 11  2019-09-10 00:00:00   有效  236.0  2019-12
# 12  2019-08-27 00:00:00   有效  149.0  2019-10
# 13  2019-09-18 00:00:00   有效  155.0  2019-10
# 14  2019-09-18 00:00:00   有效  155.0  2019-10
# 15  2019-07-30 00:00:00   有效  193.0  2019-11
# 16  2019-09-02 00:00:00   有效  150.0  2019-10
# 17  2019-12-06 00:00:00   有效  184.0  2019-11
# 18                   99   99   99.0       99
#
# 总金额：8393.338008
#   清单分类如下：
# 银行分类
# 一类准入      2000.000000
# 二类准入         5.000000
# 其他授信银行      82.785000
# 国股        6055.552898
# 大商         250.000110
# Name: 票面金额, dtype: float64
#
# 到期月
# 2019-09      43.939872
# 2019-10    6214.398136
# 2019-11    1235.000000
# 2019-12     900.000000
# Name: 票面金额, dtype: float64
#
# 175.22222222222223
